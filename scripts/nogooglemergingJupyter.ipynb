# %%
import numpy as np
import pandas as pd
import os
import hashlib

# %%
def loadTraffickCam(path):
    with open(path, 'r', encoding='utf-8') as file:  # Specify utf-8 encoding
        txt_data = file.readlines()
    
    txt_data = [line.strip().split('\t') for line in txt_data]

    columns = ['number', 'hotel_name', 'latitude', 'longitude', 'places_id']
    txt_data_df = pd.DataFrame(txt_data, columns=columns)

    txt_data_df['longitude'] = pd.to_numeric(txt_data_df['longitude'], errors='coerce')
    txt_data_df['latitude'] = pd.to_numeric(txt_data_df['latitude'], errors='coerce')
    txt_data_df.dropna(subset=['longitude', 'latitude'], inplace=True)

    return txt_data_df

# %%
#Load TraffickCam Data
traffickCamData = loadTraffickCam("hotel_info_with_places_id.txt")
traffickCamData.head
# Out:
# <bound method NDFrame.head of         number                                         hotel_name   latitude  \
# 0          390                                  Super 8 Frederick  39.402160
# 1          391  Extended Stay America - Fairbanks - Old Airpor...  64.835380
# 2          392                Hilton Hangzhou Qiandao Lake Resort  29.608190
# 3          393                                      Taj Lands End  19.043910
# 4          394        Helzear Montparnasse Rive Gauche Apartments  48.834660
# ...        ...                                                ...        ...
# 625133  694001   Hyatt Regency Lake Washington at Seattle’s So...  47.503043
# 625134  694002                                 The Beverly Hilton  34.066370
# 625135  694003               Homewood Suites by Hilton Ronkonkoma  40.812062
# 625136  694004                                  Choctaw Durant OK  33.958543
# 625137  694005                                            ???????  24.125850
#
#          longitude                    places_id
# 0       -77.408420  ChIJCWJjR0HayYkRAfWSLQl85IQ
# 1      -147.823300  ChIJqbFJVhdbMlERYHgGtF-Gv8w
# 2       119.072900  ChIJDZWWXAOLSTQR4JoKtpTbZEE
# 3        72.818790  ChIJSRH78kXJ5zsRMTuWOSp0uqI
# 4         2.325060  ChIJT1aX0LVx5kcRYawv-DeO4qU
# ...            ...                          ...
# 625133 -122.204757                         None
# 625134 -118.412804                         None
# 625135  -73.101901  ChIJY2Ubpu836IkRqyIH_SEtfo4
# 625136  -96.411831                         None
# 625137  121.641299  ChIJnbcpvw8oZjQR7Lax5V6ivvY
#
# [625138 rows x 5 columns]>

# %%
# Load sharded data
def load_sharded_dataset(root_dir):
    all_data = []
    print("after making list")
    try:
        print("after try")
        for root, dirs, files in os.walk(root_dir):
            #print("in for loop")
            #print(f"Scanning directory: {root}")  # Log current directory being scanned
            
            if not files:
                print(f"No files found in directory: {root}")
                continue  # Skip directories with no files
            
            for file in files:
                file_path = os.path.join(root, file)
                #print(f"Attempting to load file: {file_path}")  # Log which file is being loaded
                
                # Check file extension and load accordingly
                if file.endswith('.csv'):
                    try:
                        data = pd.read_csv(file_path)
                        all_data.append(data)
                        #print(f"Successfully loaded {file_path} with {len(data)} records.")
                    except Exception as e:
                        print(f"Error loading {file_path}: {e}")
                elif file.endswith('.json'):
                    try:
                        data = pd.read_json(file_path)
                        all_data.append(data)
                        #print(f"Successfully loaded {file_path} with {len(data)} records.")
                    except Exception as e:
                        print(f"Error loading {file_path}: {e}")
                else:
                    print(f"Skipping unsupported file format: {file_path}")
    
    except Exception as e:
        print(f"Exception occurred during directory traversal: {e}")
    
    # Ensure we're returning a single combined DataFrame
    if all_data:
        combined_data = pd.concat(all_data, ignore_index=True)
        combined_data.drop_duplicates(inplace=True, keep = 'first')
        combined_data.drop('images', axis=1, inplace=True)
        combined_data['hotel_name'] = combined_data['hotel_name'].str.replace('-', ' ')
        combined_data.drop_duplicates(keep = 'first', inplace=True)
        print(f"Loaded {len(all_data)} files, combined into one DataFrame.")
        return combined_data
    else:
        print("No data loaded.")
        return None

# %%
# Load booking.com Data
root_dir = 'country/United-States-of-America'
bookingData = load_sharded_dataset(root_dir)
# Out:
# after making list
# after try
# No files found in directory: country/United-States-of-America
# No files found in directory: country/United-States-of-America\Alabama
# No files found in directory: country/United-States-of-America\Alaska
# No files found in directory: country/United-States-of-America\Arizona
# No files found in directory: country/United-States-of-America\Arkansas
# No files found in directory: country/United-States-of-America\California
# No files found in directory: country/United-States-of-America\Colorado
# No files found in directory: country/United-States-of-America\Connecticut
# No files found in directory: country/United-States-of-America\Delaware
# No files found in directory: country/United-States-of-America\Florida
# No files found in directory: country/United-States-of-America\Georgia
# No files found in directory: country/United-States-of-America\Idaho
# No files found in directory: country/United-States-of-America\Illinois
# No files found in directory: country/United-States-of-America\Indiana
# No files found in directory: country/United-States-of-America\Iowa
# No files found in directory: country/United-States-of-America\Kansas
# No files found in directory: country/United-States-of-America\Kauai
# No files found in directory: country/United-States-of-America\Kentucky
# No files found in directory: country/United-States-of-America\Louisiana
# No files found in directory: country/United-States-of-America\Maine
# No files found in directory: country/United-States-of-America\Martha's-Vineyard
# No files found in directory: country/United-States-of-America\Maryland
# No files found in directory: country/United-States-of-America\Massachusetts
# No files found in directory: country/United-States-of-America\Maui
# No files found in directory: country/United-States-of-America\Michigan
# No files found in directory: country/United-States-of-America\Minnesota
# No files found in directory: country/United-States-of-America\Mississippi
# No files found in directory: country/United-States-of-America\Missouri
# No files found in directory: country/United-States-of-America\Montana
# No files found in directory: country/United-States-of-America\Mount-Desert-Island
# No files found in directory: country/United-States-of-America\Nebraska
# No files found in directory: country/United-States-of-America\Nevada
# No files found in directory: country/United-States-of-America\New-Hampshire
# No files found in directory: country/United-States-of-America\New-Jersey
# No files found in directory: country/United-States-of-America\New-Mexico
# No files found in directory: country/United-States-of-America\New-York-State
# No files found in directory: country/United-States-of-America\North-Carolina
# No files found in directory: country/United-States-of-America\North-Dakota
# No files found in directory: country/United-States-of-America\Ohio
# No files found in directory: country/United-States-of-America\Oklahoma
# No files found in directory: country/United-States-of-America\Orcas-Island
# No files found in directory: country/United-States-of-America\Oregon
# No files found in directory: country/United-States-of-America\Pennsylvania
# No files found in directory: country/United-States-of-America\Rhode-Island
# No files found in directory: country/United-States-of-America\Sanibel-Island
# No files found in directory: country/United-States-of-America\South-Carolina
# No files found in directory: country/United-States-of-America\South-Dakota
# No files found in directory: country/United-States-of-America\Tennessee
# No files found in directory: country/United-States-of-America\Texas
# No files found in directory: country/United-States-of-America\The-Big-Island
# No files found in directory: country/United-States-of-America\Utah
# No files found in directory: country/United-States-of-America\Vermont
# No files found in directory: country/United-States-of-America\Virginia
# No files found in directory: country/United-States-of-America\Washington-State
# No files found in directory: country/United-States-of-America\West-Virginia
# No files found in directory: country/United-States-of-America\Whidbey-Island
# No files found in directory: country/United-States-of-America\Wisconsin
# No files found in directory: country/United-States-of-America\Wyoming
# Loaded 5154 files, combined into one DataFrame.

# %%
def split_gps_column(sharded_data):
    if 'gps' in sharded_data.columns:
        # Split the 'gps' column on the delimiter (assuming comma, adjust if necessary)
        sharded_data[['latitude', 'longitude']] = sharded_data['gps'].str.split(',', expand=True)
        
        # Convert latitude and longitude to numeric types
        sharded_data['latitude'] = pd.to_numeric(sharded_data['latitude'], errors='coerce')
        sharded_data['longitude'] = pd.to_numeric(sharded_data['longitude'], errors='coerce')

        # Drop the 'gps' column after splitting
        sharded_data.drop('gps', axis=1, inplace=True)
    
    return sharded_data

# %%
split_gps_column(bookingData)
# Out:
#                                                hotel_name date_accessed  \
# 0       Candlewood Suites Alabaster, an IHG Hotel (Hotel)    2024-08-26
# 67      Fairfield by Marriott Inn & Suites Albertville...    2024-10-15
# 102     Microtel Inn & Suites by Wyndham Albertville (...    2024-10-27
# 135     InTown Suites Extended Stay Birmingham AL   Ho...    2024-08-29
# 169                              Econo Lodge Boaz (Hotel)    2024-10-27
# ...                                                   ...           ...
# 255764                 The Hatchet Resort (Resort), Moran    2024-07-01
# 255834             Togwotee Mountain Lodge (Lodge), Moran    2024-07-01
# 255878    Cobblestone Hotel & Suites   Torrington (Hotel)    2024-09-07
# 255971  Holiday Inn Express Hotel & Suites Torrington,...    2024-09-07
# 256021                     King's Inn (Hotel), Torrington    2024-09-07
#
#                                                   address rating  \
# 0       1004 Balmoral Drive, Alabaster, AL 35007, Unit...    8.1
# 67      328 George Wallace Drive, Albertville, 35951, ...    9.1
# 102     220 Alabama Highway 75 North, Albertville, AL ...    8.3
# 135     1840 Southpark Drive, Birmingham, AL 35244, Un...      7
# 169     761 US Hwy 431, Boaz, 35957, United States of ...    7.5
# ...                                                   ...    ...
# 255764  19980 East Hwy 287, Moran, WY 83013, United St...    7.8
# 255834  27655 Highway 26 & 287 (16.5 miles east of Gra...    7.2
# 255878  1306 Main St, Torrington, WY 82240, United Sta...    8.6
# 255971  1700 East Valley Road, Torrington, WY 82240, U...    7.8
# 256021  1555 Main Street, Torrington, WY 82240, United...    5.4
#
#                                                       url   latitude  \
# 0       https://www.booking.com/hotel/us/candlewood-su...  33.232859
# 67      https://www.booking.com/hotel/us/fairfield-by-...  34.294313
# 102     https://www.booking.com/hotel/us/microtel-inn-...  34.276824
# 135     https://www.booking.com/hotel/us/intown-suites...  33.349074
# 169     https://www.booking.com/hotel/us/econo-lodge-b...  34.197369
# ...                                                   ...        ...
# 255764  https://www.booking.com/hotel/us/the-hatchet-r...  43.825107
# 255834  https://www.booking.com/hotel/us/togwotee-moun...  43.818566
# 255878  https://www.booking.com/hotel/us/cobblestone-a...  42.058363
# 255971  https://www.booking.com/hotel/us/holiday-inn-e...  42.053325
# 256021  https://www.booking.com/hotel/us/king-39-s-inn...  42.060689
#
#          longitude
# 0       -86.799270
# 67      -86.252364
# 102     -86.203203
# 135     -86.794395
# 169     -86.151096
# ...            ...
# 255764 -110.358680
# 255834 -110.199829
# 255878 -104.184830
# 255971 -104.162968
# 256021 -104.183739
#
# [4943 rows x 7 columns]

# %%
latlng = np.vstack([np.array(bookingData["latitude"]), np.array(bookingData["longitude"])])

trafficlatlng = np.vstack([np.array(traffickCamData["latitude"]), np.array(traffickCamData["longitude"])])

bookingHotelNames = np.vstack([np.array(bookingData["hotel_name"])])

trafficHotelNames = np.vstack([np.array(traffickCamData["hotel_name"])])

bookingHotelURL = np.vstack([np.array(bookingData["url"])])

trafficHotelID = np.vstack([np.array(traffickCamData["places_id"])])

latlng.shape,trafficlatlng.shape

bookingHotelNames.shape,trafficHotelNames.shape

print(bookingHotelNames[:10])
print(trafficHotelID[:10])
# Out:
# [['Candlewood Suites Alabaster, an IHG Hotel (Hotel)'
#   'Fairfield by Marriott Inn & Suites Albertville (Hotel)'
#   'Microtel Inn & Suites by Wyndham Albertville (Hotel)' ...
#   'Cobblestone Hotel & Suites   Torrington (Hotel)'
#   'Holiday Inn Express Hotel & Suites Torrington, an IHG Hotel (Hotel)'
#   "King's Inn (Hotel), Torrington"]]
# [['ChIJCWJjR0HayYkRAfWSLQl85IQ' 'ChIJqbFJVhdbMlERYHgGtF-Gv8w'
#   'ChIJDZWWXAOLSTQR4JoKtpTbZEE' ... 'ChIJY2Ubpu836IkRqyIH_SEtfo4' None
#   'ChIJnbcpvw8oZjQR7Lax5V6ivvY']]

# %%
def remove_after_near(s):
    index = s.lower().find("near")
    return s[:index].strip() if index != -1 else s

# %%
# List of phrases to omit
phrases_to_omit = ["hotel", "motel", "bed and breakfast", "inn ", "&", "suites", " and", " by", " or", 
                   " the", " an", "ihg", " at", " area", " north", " south", " east", "west "]

# Makes the hotel names into a numpy array
cleaned_hotel_names = np.array([
    np.array([name for name in bookingHotelNames[0]])
])

cleaned_hotel_names_traffic = np.array([
    np.array([name for name in trafficHotelNames[0]])
])

# Takes out all punctuation
unwanted_chars = "()-.,!?"
translation_table = str.maketrans('', '', unwanted_chars)
cleaned_hotel_names = np.char.translate(cleaned_hotel_names, translation_table)
cleaned_hotel_names_traffic = np.char.translate(cleaned_hotel_names_traffic, translation_table)

# Makes all words lower case
cleaned_hotel_names = np.char.lower(cleaned_hotel_names)
cleaned_hotel_names_traffic = np.char.lower(cleaned_hotel_names_traffic)

# Takes out all the phrases ot omit
for phrase in phrases_to_omit:
    cleaned_hotel_names = np.char.replace(cleaned_hotel_names, phrase, "")
    cleaned_hotel_names_traffic = np.char.replace(cleaned_hotel_names_traffic, phrase, "")

cleaned_hotel_names = np.char.replace(cleaned_hotel_names, '  ', ' ')
cleaned_hotel_names_traffic = np.char.replace(cleaned_hotel_names_traffic, '  ', ' ')

# Cleans up all the spaces
while np.any(np.char.find(cleaned_hotel_names, '  ') != -1):
    cleaned_hotel_names = np.char.replace(cleaned_hotel_names, '  ', ' ')
while np.any(np.char.find(cleaned_hotel_names_traffic, '  ') != -1):
    cleaned_hotel_names_traffic = np.char.replace(cleaned_hotel_names_traffic, '  ', ' ')

# Removes all words after the word "near"
remove_after_near_vec = np.vectorize(remove_after_near)
cleaned_hotel_names = remove_after_near_vec(cleaned_hotel_names)
cleaned_hotel_names_traffic = remove_after_near_vec(cleaned_hotel_names_traffic)

# Cleaned hotel names
cleanedBookingHotelNames = np.char.strip(cleaned_hotel_names)  # Remove any leading/trailing spaces
cleanedTrafficHotelNames = np.char.strip(cleaned_hotel_names_traffic)

print(cleanedBookingHotelNames[:10])
print(cleanedTrafficHotelNames[:10])
# Out:
# [['candlewood alabaster' 'fairfield marriott albertville'
#   'microtel wyndham albertville' ... 'cobblestone torrington'
#   'holiday express torrington' "king's torrington"]]
# [['super 8 frederick' 'extended stay america fairbanks old airport way'
#   'hilton hangzhou qiandao lake resort' ... 'homewood hilton ronkonkoma'
#   'choctaw durant ok' '']]

# %%
# Initialize arrays to store the 10 closest indices and distances for each point
from scipy.spatial.distance import cdist
from rapidfuzz import fuzz
from rapidfuzz import utils

latlon_small = latlng.T  # Now (3906, 2)
latlon_large = trafficlatlng.T  # Now (625138, 2)
# Compute the pairwise Euclidean distances

#hotel_name_small = bookingHotelNames.T
hotel_name_small = cleanedBookingHotelNames.T
hotel_name_large = cleanedTrafficHotelNames.T

booking_urls = bookingHotelURL.T
traffic_places_id = trafficHotelID.T

unique_latlon_large = np.unique(latlon_large, axis=0)

num_small = latlon_small.shape[0]

closest_indices = []
closest_distances = []
similarity_scores = []

distance_threshold = 0.0045

# Loop through each point in the smaller array
for i in range(num_small):
    # Compute distances between the ith point in latlon_small and all points in latlon_large
    distances = cdist(latlon_small[i:i+1], latlon_large).flatten()  # distances shape (625138,)

    # Filter indices where the distance is within 500 meters (threshold)
    within_threshold_idx = np.where(distances <= distance_threshold)[0]
    
    # Store the closest indices and corresponding distances
    closest_indices.append(within_threshold_idx)
    closest_distances.append(distances[within_threshold_idx])

    print(f"Points within 500 meters of point {i}: {within_threshold_idx}, Distances: {distances[within_threshold_idx]}")

    ref_hotel_name = hotel_name_small[i].flatten()

    # Compute similarity scores for points within the threshold
    similarity_scores_for_point = []
    for j in range(len(within_threshold_idx)):
        closest_hotel_name = hotel_name_large[within_threshold_idx[j]].flatten()

        # Compute the similarity score using fuzzy string matching
        similarity_score = fuzz.token_set_ratio(str(ref_hotel_name), str(closest_hotel_name), processor=utils.default_process)
        similarity_scores_for_point.append(similarity_score)

        if similarity_score >= 85.1:
            print(f"Similarity score between '{ref_hotel_name}' and '{closest_hotel_name}': {similarity_score}")
    
    similarity_scores.append(similarity_scores_for_point)

    print("-----------")

    #if i > 250:
        #break
# Out:
# Points within 500 meters of point 0: [ 71625 146709 152600], Distances: [0.00075076 0.00013271 0.00099801]
# Similarity score between '['candlewood alabaster']' and '['candlewood alabaster']': 100.0
# Similarity score between '['candlewood alabaster']' and '['candlewood alabaster alabama']': 100.0
# -----------
# Points within 500 meters of point 1: [], Distances: []
# -----------
# Points within 500 meters of point 2: [ 4514 10971 38765 60150], Distances: [0.00143479 0.00134634 0.00345048 0.00334422]
# Similarity score between '['microtel wyndham albertville']' and '['microtel wyndham albertville']': 100.0
# -----------
# Points within 500 meters of point 3: [ 55525 388677], Distances: [0.00182846 0.00196707]
# -----------
# Points within 500 meters of point 4: [156508], Distances: [0.00109385]
# Similarity score between '['econo lodge boaz']' and '['econo lodge']': 100.0
# -----------
# Points within 500 meters of point 5: [18662], Distances: [0.00038994]
# Similarity score between '['key boaz']' and '['key boaz al']': 100.0
# -----------
# Points within 500 meters of point 6: [  8254 256777], Distances: [0.00197575 0.00177408]
# Similarity score between '['hampton calera']' and '['hampton calera']': 100.0
# Similarity score between '['hampton calera']' and '['hampton calera']': 100.0
# -----------
# Points within 500 meters of point 7: [  2850  15382  15757  17078  60198  71051 152192], Distances: [0.00315809 0.00427458 0.00193151 0.00276004 0.00022845 0.00355511
#  0.00344723]
# Similarity score between '['best western fairwinds cullman']' and '['best western fairwinds inn']': 91.66666666666667
# -----------
# Points within 500 meters of point 8: [], Distances: []
# -----------
# Points within 500 meters of point 9: [  2850  15382  15757  17078  60198  71051 152192], Distances: [0.00435631 0.00192846 0.00197861 0.00234089 0.00373001 0.00045733
#  0.0004996 ]
# Similarity score between '['comfort cullman i 65 exit 310']' and '['comfort cullman']': 100.0
# -----------
# Points within 500 meters of point 10: [  2850  15382  15757  17078  71051 152192], Distances: [0.0039961  0.00146414 0.0041513  0.00291913 0.00301015 0.00314226]
# -----------
# Points within 500 meters of point 11: [  2850  15382  15757  17078  60198  71051 152192], Distances: [0.00436272 0.00191085 0.0020063  0.00234766 0.00375844 0.00046902
#  0.00051946]
# Similarity score between '['hampton cullman']' and '['hampton cullman']': 100.0
# -----------
# Points within 500 meters of point 12: [ 15757  71051 152192], Distances: [0.0044487  0.00338368 0.00337724]
# -----------
# Points within 500 meters of point 13: [ 15757  60198  71051 152192], Distances: [0.00350217 0.00395189 0.00394853 0.00382385]
# Similarity score between '['la quinta wyndham cullman']' and '['la quinta cullman']': 100.0
# -----------
# Points within 500 meters of point 14: [  2850  15382  15757  17078  60198  71051 152192], Distances: [0.00447801 0.00383056 0.00133522 0.00297959 0.00198346 0.00237825
#  0.00223692]
# Similarity score between '['quality cullman i 65 exit 310 inn']' and '['quality cullman']': 100.0
# -----------
# Points within 500 meters of point 15: [ 2850 61074], Distances: [0.00429355 0.00044843]
# -----------
# Points within 500 meters of point 16: [  2850  15382  15757  17078  60198  71051 152192], Distances: [0.00191923 0.00139314 0.00208019 0.00044773 0.00311976 0.00208083
#  0.00211354]
# Similarity score between '['sleep cullman i 65 exit 310']' and '['sleep cullman']': 100.0
# -----------
# Points within 500 meters of point 17: [], Distances: []
# -----------
# Points within 500 meters of point 18: [ 4425 19022 34939 61396], Distances: [0.00104928 0.00411394 0.00263593 0.00232038]
# -----------
# Points within 500 meters of point 19: [ 4425 19022 34939 61396], Distances: [0.00116231 0.00417277 0.00273722 0.00237382]
# -----------
# Points within 500 meters of point 20: [ 4425 19022 34939 61396], Distances: [1.53996944e-03 1.62236780e-03 8.26672710e-05 5.89221926e-04]
# Similarity score between '['econo lodge fort payne']' and '['econo lodge fort payne']': 100.0
# -----------
# Points within 500 meters of point 21: [], Distances: []
# -----------
# Points within 500 meters of point 22: [ 4425 19022 34939 61396], Distances: [0.00309771 0.00053245 0.00178272 0.00176861]
# Similarity score between '['holiday express fort payne']' and '['holiday express ft payne']': 96.0
# -----------
# Points within 500 meters of point 23: [22538], Distances: [0.00042502]
# -----------
# Points within 500 meters of point 24: [21659 53928], Distances: [0.0006798  0.00170821]
# Similarity score between '['hampton guntersville']' and '['hampton guntersville']': 100.0
# -----------
# Points within 500 meters of point 25: [19962], Distances: [0.00045497]
# Similarity score between '['wyndham garden lake guntersville']' and '['wyndham garden lake guntersville']': 100.0
# -----------
# Points within 500 meters of point 26: [34502], Distances: [0.00011238]
# -----------
# Points within 500 meters of point 27: [27323], Distances: [0.00020073]
# Similarity score between '['courtyard birmingham hoover']' and '['courtyard marriott birmingham hoover']': 100.0
# -----------
# Points within 500 meters of point 28: [  6882  18721  20262 621792], Distances: [0.00070901 0.00209643 0.00207405 0.00022177]
# Similarity score between '['embassy hilton birmingham hoover']' and '['embassy birmingham/hoover']': 100.0
# Similarity score between '['embassy hilton birmingham hoover']' and '['embassy']': 100.0
# -----------
# Points within 500 meters of point 29: [20262 31003 49113], Distances: [0.00384092 0.00166274 0.00084274]
# Similarity score between '['hampton birmingham hoover galleria']' and '['hampton birmingham hoover']': 100.0
# -----------
# Points within 500 meters of point 30: [18721 21701], Distances: [0.00355932 0.00080331]
# Similarity score between '['holiday birmingham hoover']' and '['holiday birmingham hoover']': 100.0
# -----------
# Points within 500 meters of point 31: [23807 28095], Distances: [0.00061404 0.00083598]
# -----------
# Points within 500 meters of point 32: [  6882  18721  20262  49113 621792], Distances: [0.00216586 0.00421107 0.00044087 0.00274611 0.00226661]
# Similarity score between '['hyatt place birmingham hoover']' and '['hyatt place birmingham/hoover']': 100.0
# -----------
# Points within 500 meters of point 33: [23807 28095], Distances: [0.00142195 0.00034035]
# Similarity score between '['la quinta wyndham birmingham hoover']' and '['la quinta birmingham hoover']': 100.0
# -----------
# Points within 500 meters of point 34: [  6882  18721  20262  21701 621792], Distances: [0.00228063 0.00025352 0.00412995 0.00365602 0.00192848]
# Similarity score between '['microtel wyndham hoover birmingham']' and '['microtel wyndham hoover/birmingham']': 100.0
# -----------
# Points within 500 meters of point 35: [13806], Distances: [0.00012042]
# Similarity score between '['residence birmingham hoover']' and '['residence marriott birmingham/hoover']': 100.0
# -----------
# Points within 500 meters of point 36: [ 8413 10198 25496 36187 53854 98721], Distances: [0.0022156  0.00147986 0.00189497 0.00049826 0.00286978 0.00309874]
# Similarity score between '['fairfield marriott montgomery airport hope hul']' and '['fairfield marriott montgomery airport']': 100.0
# -----------
# Points within 500 meters of point 37: [ 8413 10198 25496 36187 53854 98721], Distances: [0.00227763 0.00137723 0.00190701 0.00052436 0.0028647  0.00309459]
# Similarity score between '['hampton montgomery airport hope hul']' and '['6 montgomery airport hope hull al']': 85.29411764705883
# -----------
# Points within 500 meters of point 38: [ 8413 10198 25496 36187 53854 98721], Distances: [0.00130717 0.00248444 0.00033241 0.00114716 0.001237   0.00146488]
# Similarity score between '['holiday montgomery airport hope hul']' and '['holiday montgomery airport']': 100.0
# Similarity score between '['holiday montgomery airport hope hul']' and '['6 montgomery airport hope hull al']': 85.29411764705883
# -----------
# Points within 500 meters of point 39: [ 8413 10198 25496 36187 53854 98721], Distances: [0.00164209 0.00407574 0.00135097 0.00274642 0.00065164 0.00054261]
# Similarity score between '['6 montgomery al airport hope hull']' and '['6 montgomery airport hope hull al']': 100.0
# -----------
# Points within 500 meters of point 40: [ 14501  18663  23282  24053  26693  36967  53532  93721 110730 144835
#  146537 582568 622899], Distances: [0.0006601  0.00266343 0.00233453 0.00244544 0.00369072 0.00320851
#  0.00324726 0.00164479 0.00282133 0.00249116 0.00363608 0.00078593
#  0.00340107]
# Similarity score between '['best western plus mobile']' and '['6 mobile']': 85.71428571428571
# -----------
# Points within 500 meters of point 41: [ 12642  18080  33628 151299 154797 258422], Distances: [0.00164905 0.00362417 0.00038653 0.00415734 0.00230169 0.0025297 ]
# Similarity score between '['candlewood mobile downtown']' and '['candlewood downtown']': 100.0
# -----------
# Points within 500 meters of point 42: [ 36543  41546  57585 105980], Distances: [6.01664358e-05 6.85973760e-04 1.65043631e-03 1.58717989e-03]
# -----------
# Points within 500 meters of point 43: [ 14784  18606  31966  38150  38174  38670  40763  43586  53913  94186
#  102740 621766], Distances: [0.00385728 0.00151792 0.00074474 0.00056097 0.00228352 0.00149983
#  0.00062047 0.00069954 0.00056323 0.00265737 0.00313048 0.00107946]
# Similarity score between '['comfort mobile tillmans corner']' and '['baymont mobile / tillmans corner']': 86.66666666666667
# Similarity score between '['comfort mobile tillmans corner']' and '['comfort mobile']': 100.0
# Similarity score between '['comfort mobile tillmans corner']' and '['6 mobile tillmans corner']': 95.65217391304348
# -----------
# Points within 500 meters of point 44: [18527 20433 27153 35479 36727 40281 66790], Distances: [0.00075641 0.00071946 0.00132326 0.00041803 0.00220198 0.00088584
#  0.00088117]
# Similarity score between '['courtyard mobile']' and '['courtyard marriott mobile']': 100.0
# -----------
# Points within 500 meters of point 45: [ 14501  18663  23282  24053  26693  36967  53532  93721 110730 144835
#  146537 582568 622899], Distances: [0.00093038 0.00269475 0.00246806 0.00235359 0.00374765 0.00328661
#  0.00332364 0.00186462 0.00292027 0.00237592 0.00345794 0.00050636
#  0.00332019]
# Similarity score between '['days wyndham mobile i 65']' and '['6 mobile']': 85.71428571428571
# Similarity score between '['days wyndham mobile i 65']' and '['days wyndham mobile i65']': 93.61702127659575
# -----------
# Points within 500 meters of point 46: [ 35878 150577], Distances: [0.00053691 0.00040334]
# -----------
# Points within 500 meters of point 47: [ 14501  18663  27153  36727  36967  40281  66790  93721 146537 582568], Distances: [0.00293851 0.00050891 0.00373988 0.0029887  0.00041374 0.00416017
#  0.00417357 0.0043047  0.00277788 0.0032993 ]
# Similarity score between '['drury mobile']' and '['6 mobile']': 85.71428571428571
# Similarity score between '['drury mobile']' and '['drury mobile al']': 100.0
# -----------
# Points within 500 meters of point 48: [ 39974  40142 146777], Distances: [0.00036368 0.00089924 0.00100096]
# Similarity score between '['extended stay america mobile spring hill']' and '['extended stay america mobile spring hill']': 100.0
# -----------
# Points within 500 meters of point 49: [18527 18663 20433 27153 35479 36727 36967 40281 66790], Distances: [0.00159935 0.0044031  0.00155591 0.00066635 0.0010991  0.0014146
#  0.0037081  0.00053415 0.00054519]
# Similarity score between '['fairfield mobile']' and '['fairfield marriott mobile']': 100.0
# -----------
# Points within 500 meters of point 50: [18527 18663 20433 27153 35479 36727 36967 40281 66790], Distances: [0.00271493 0.00344045 0.00266588 0.00080921 0.00215904 0.00022002
#  0.00269587 0.00127251 0.00128397]
# Similarity score between '['family inns of america mobile']' and '['family inns of america mobile']': 100.0
# -----------
# Points within 500 meters of point 51: [ 12095  12851  14970  18080  23968  26204  52047 147401 151299], Distances: [0.00342513 0.00409988 0.00022672 0.00341421 0.00354889 0.00270523
#  0.00336176 0.00394679 0.0037191 ]
# -----------
# Points within 500 meters of point 52: [ 12095  12642  14970  18080  23968  26204  33628  52047 151299 154797
#  258422], Distances: [0.00187698 0.00211371 0.00327178 0.00050261 0.00355089 0.00348845
#  0.00368316 0.0028897  0.00230743 0.00261997 0.00279424]
# Similarity score between '['hampton mobile downtown historic district']' and '['hampton mobile downtown historic district']': 100.0
# Similarity score between '['hampton mobile downtown historic district']' and '['quality downtown historic district']': 86.66666666666667
# -----------
# Points within 500 meters of point 53: [18527 20433 27153 35479 36727 40281 66790], Distances: [0.00087016 0.00087855 0.0020508  0.00102303 0.00289421 0.00163975
#  0.00163652]
# Similarity score between '['hampton mobile i 65@ airport boulevard']' and '['hampton mobile i65 airport blvd']': 85.29411764705883
# -----------
# Points within 500 meters of point 54: [18267 18461], Distances: [0.00052113 0.00057748]
# -----------
# Points within 500 meters of point 55: [ 12642  18080  23968  26204  33628  52047 150432 151299 154797 258422], Distances: [0.00252739 0.00318714 0.00325135 0.00390578 0.00293066 0.00271319
#  0.00342134 0.00184718 0.00035914 0.0039641 ]
# Similarity score between '['hilton garden mobile downtown']' and '['hilton garden mobile downtown']': 100.0
# -----------
# Points within 500 meters of point 56: [ 14501  18663  27153  35479  36727  36967  40281  66790 146537 582568], Distances: [0.00326424 0.00109662 0.00312803 0.00440498 0.00235075 0.00037041
#  0.00356086 0.00357394 0.00338764 0.00382113]
# Similarity score between '['hilton garden mobile i 65 airport boulevard']' and '['hilton garden mobile west']': 88.88888888888889
# -----------
# Points within 500 meters of point 57: [ 39974  40142 146777], Distances: [1.17816791e-03 1.86122852e-03 7.17741597e-05]
# -----------
# Points within 500 meters of point 58: [450545], Distances: [0.00160636]
# Similarity score between '['holiday express mobile university']' and '['holiday express mobile university']': 100.0
# -----------
# Points within 500 meters of point 59: [ 14501  23282  24053  26693  53532  93721 110730 144835 582568 622899], Distances: [0.00337805 0.00228371 0.0004647  0.00209701 0.0020461  0.00290038
#  0.00209442 0.00041761 0.00269242 0.00059978]
# Similarity score between '['holiday mobile airport']' and '['holiday mobile airport']': 100.0
# Similarity score between '['holiday mobile airport']' and '['6 mobile']': 85.71428571428571
# -----------
# Points within 500 meters of point 60: [ 12851  14970  18080  23968  26204  52047 147401 150432 151299 154797
#  469657], Distances: [0.00176571 0.00349041 0.00422522 0.00018412 0.00104103 0.00085699
#  0.00125469 0.00209556 0.00171831 0.00356501 0.00359099]
# Similarity score between '['holiday mobile downtown historic district']' and '['hampton mobile downtown historic district']': 89.1891891891892
# Similarity score between '['holiday mobile downtown historic district']' and '['quality downtown historic district']': 86.66666666666667
# -----------
# Points within 500 meters of point 61: [258600 347363 554642], Distances: [0.00133856 0.00108482 0.00109641]
# Similarity score between '['home2 hilton mobile i 65 government boulevard']' and '['home2 hilton mobile i65 government bl']': 89.55223880597015
# Similarity score between '['home2 hilton mobile i 65 government boulevard']' and '['home2 hilton mobile i65 government boulevard']': 96.62921348314607
# Similarity score between '['home2 hilton mobile i 65 government boulevard']' and '['tru hilton mobile']': 86.66666666666667
# -----------
# Points within 500 meters of point 62: [18267 18461], Distances: [0.00052185 0.00046793]
# Similarity score between '['homewood hilton mobile']' and '['homewood hilton mobile']': 100.0
# -----------
# Points within 500 meters of point 63: [18527 20433 27153 35479 36727 40281 66790], Distances: [0.00086196 0.00087255 0.00208294 0.00103679 0.00292883 0.00166899
#  0.00166555]
# Similarity score between '['homewood mobile']' and '['homewood hilton mobile i65/airport blvd al']': 100.0
# -----------
# Points within 500 meters of point 64: [624667], Distances: [0.00441154]
# -----------
# Points within 500 meters of point 65: [ 18606  31966  38150  38174  38670  40763  43586  53913  94186 102740
#  347367 621766], Distances: [0.00411897 0.00413221 0.00372442 0.00226481 0.0032549  0.00370348
#  0.00408991 0.00393326 0.00131614 0.00061878 0.00179985 0.00425664]
# Similarity score between '['intown extended stay mobile al tillmans corner']' and '['6 mobile tillmans corner']': 95.65217391304348
# Similarity score between '['intown extended stay mobile al tillmans corner']' and '['6 mobile al']': 90.0
# -----------
# Points within 500 meters of point 66: [ 14501  18663  23282  24053  26693  36967  53532  93721 110730 144835
#  146537 582568 622899], Distances: [0.00083096 0.00210478 0.0029048  0.00294845 0.00427446 0.00269254
#  0.00383103 0.00213914 0.00340227 0.00296868 0.00314192 0.00085866
#  0.0039149 ]
# Similarity score between '['la quinta wyndham mobile']' and '['la quinta mobile']': 100.0
# Similarity score between '['la quinta wyndham mobile']' and '['6 mobile']': 85.71428571428571
# -----------
# Points within 500 meters of point 67: [14784 20312 21854], Distances: [0.00263158 0.00077899 0.00075142]
# Similarity score between '["la quinta wyndham mobile tillman's corner"]' and '["la quinta mobiletillman's corner"]': 87.67123287671232
# -----------
# Points within 500 meters of point 68: [ 12851  14970  23968  26204  52047 147401 150432 151299 469657], Distances: [0.00026513 0.00390691 0.00168257 0.00168782 0.00235711 0.00029852
#  0.00264373 0.00325702 0.00259129]
# Similarity score between '['malaga mobile']' and '['malaga mobile al']': 100.0
# -----------
# Points within 500 meters of point 69: [29170], Distances: [0.00028817]
# Similarity score between '['mobile marriott']' and '['marriott mobile']': 100.0
# -----------
# Points within 500 meters of point 70: [ 14501  23282  24053  26693  53532  93721 110730 144835 582568 622899], Distances: [0.00334149 0.00109211 0.0017978  0.00050219 0.00011469 0.00213861
#  0.00051042 0.00200989 0.00347725 0.00175621]
# Similarity score between '['6 mobile al airport blvd']' and '['6 mobile']': 100.0
# -----------
# Points within 500 meters of point 71: [ 14501  18663  23282  24053  26693  36967  53532  93721 110730 144835
#  582568 622899], Distances: [0.00146753 0.00395035 0.00095852 0.00236389 0.00253704 0.00429602
#  0.00203748 0.00010754 0.00154794 0.00253508 0.00228667 0.00306463]
# Similarity score between '['oyo mobile al i 65 airport blvd']' and '['6 mobile']': 85.71428571428571
# -----------
# Points within 500 meters of point 72: [ 14501  23282  24053  26693  53532  93721 110730 144835 582568 622899], Distances: [0.0033999  0.00118676 0.00172971 0.00045269 0.00022912 0.00222686
#  0.00061721 0.00193814 0.003485   0.00164129]
# Similarity score between '['quality airport blvd i 65 mobile']' and '['quality']': 100.0
# Similarity score between '['quality airport blvd i 65 mobile']' and '['6 mobile']': 85.71428571428571
# -----------
# Points within 500 meters of point 73: [ 12851  14970  18080  23968  26204  52047 147401 150432 151299 154797
#  469657], Distances: [0.00154623 0.00264072 0.00417655 0.0009652  0.00023662 0.00133888
#  0.00119823 0.00305425 0.00223931 0.00421068 0.00397709]
# Similarity score between '['quality downtown historic district mobile']' and '['hampton mobile downtown historic district']': 89.1891891891892
# Similarity score between '['quality downtown historic district mobile']' and '['quality downtown historic district']': 100.0
# -----------
# Points within 500 meters of point 74: [ 12095  12642  14970  18080  26204  33628  52047 151299 154797 258422], Distances: [0.00085773 0.00226187 0.00362637 0.00063594 0.00443372 0.00386041
#  0.00397211 0.00343163 0.00351526 0.00228701]
# Similarity score between '['renaissance mobile riverview plaza']' and '['renaissance mobile riverview plaza']': 100.0
# -----------
# Points within 500 meters of point 75: [18527 18663 20433 27153 35479 36727 36967 40281 66790], Distances: [0.00158117 0.00442116 0.00153762 0.00066653 0.00108005 0.00142419
#  0.00372561 0.00052078 0.0005316 ]
# Similarity score between '['residence mobile']' and '['residence marriott mobile']': 100.0
# -----------
# Points within 500 meters of point 76: [ 14501  23282  24053  26693  53532  93721 110730 144835 582568 622899], Distances: [0.00419329 0.00304811 0.00129978 0.00250596 0.00260384 0.00373087
#  0.00276728 0.00119686 0.00338454 0.00073715]
# Similarity score between '['springhill marriott mobile']' and '['6 mobile']': 85.71428571428571
# Similarity score between '['springhill marriott mobile']' and '['springhill mobile']': 100.0
# Similarity score between '['springhill marriott mobile']' and '['springhill marriott']': 100.0
# -----------
# Points within 500 meters of point 77: [37103], Distances: [0.00037336]
# Similarity score between '['super 8 wyndham mobile']' and '['super 8 mobile']': 100.0
# -----------
# Points within 500 meters of point 78: [ 14501  18663  23282  24053  26693  36967  53532  93721 110730 144835
#  146537 582568 622899], Distances: [0.00093038 0.00269475 0.00246806 0.00235359 0.00374765 0.00328661
#  0.00332364 0.00186462 0.00292027 0.00237592 0.00345794 0.00050636
#  0.00332019]
# Similarity score between '['super 8 wyndham mobile i 65']' and '['6 mobile']': 85.71428571428571
# -----------
# Points within 500 meters of point 79: [ 12095  12642  12851  14970  18080  23968  26204  52047 147401 150432
#  151299 154797], Distances: [0.00437262 0.00438438 0.00245508 0.0027658  0.003302   0.00079028
#  0.00086979 0.00044266 0.00199722 0.00289451 0.00121021 0.00318434]
# Similarity score between '['the admiral downtown historic district mobile']' and '['hampton mobile downtown historic district']': 89.1891891891892
# Similarity score between '['the admiral downtown historic district mobile']' and '['quality downtown historic district']': 86.66666666666667
# Similarity score between '['the admiral downtown historic district mobile']' and '['the admiral']': 100.0
# -----------
# Points within 500 meters of point 80: [ 12095  12642  18080  33628  52047 151299 154797 258422], Distances: [0.00295729 0.00013881 0.00199809 0.00166012 0.00435465 0.00348792
#  0.00230591 0.00130173]
# Similarity score between '['the battle house renaissance mobile spa']' and '['the battle house renaissance mobile spa']': 100.0
# Similarity score between '['the battle house renaissance mobile spa']' and '['the battle house mobile al']': 93.87755102040816
# -----------
# Points within 500 meters of point 81: [18527 18663 20433 27153 35479 36727 36967 40281 66790], Distances: [0.00169884 0.00430946 0.00165318 0.00049646 0.00117354 0.00124703
#  0.00360377 0.00046404 0.00047732]
# -----------
# Points within 500 meters of point 82: [258600 347363 554642], Distances: [1.83145530e-03 1.15560852e-03 8.07332651e-05]
# Similarity score between '['tru hilton mobile']' and '['home2 hilton mobile i65 government bl']': 86.66666666666667
# Similarity score between '['tru hilton mobile']' and '['home2 hilton mobile i65 government boulevard']': 86.66666666666667
# Similarity score between '['tru hilton mobile']' and '['tru hilton mobile']': 100.0
# -----------
# Points within 500 meters of point 83: [ 28652  29710  31344  44012  93182 258908 622230], Distances: [4.22505680e-03 2.27414270e-03 7.25603197e-05 4.31051041e-04
#  3.52504823e-03 3.71331669e-03 6.09526636e-04]
# Similarity score between '['baymont wyndham montgomery al']' and '['baymont montgomery']': 100.0
# Similarity score between '['baymont wyndham montgomery al']' and '['6 montgomery']': 90.9090909090909
# -----------
# Points within 500 meters of point 84: [ 8413 10198 25496 36187 53854 98721], Distances: [0.00045751 0.00328882 0.001262   0.00153586 0.00210695 0.00226375]
# Similarity score between '['comfort airport montgomery']' and '['comfort airport']': 100.0
# -----------
# Points within 500 meters of point 85: [ 28652  29710  93182 147763 254009 619978], Distances: [0.00128545 0.00330742 0.00275934 0.00026821 0.0040481  0.00056827]
# Similarity score between '['drury montgomery']' and '['6 montgomery']': 90.9090909090909
# Similarity score between '['drury montgomery']' and '['drury s montgomery alabama']': 100.0
# Similarity score between '['drury montgomery']' and '['drury montgomery al']': 100.0
# -----------
# Points within 500 meters of point 86: [  4497   5735  11259  15330 439356 510839], Distances: [1.76034269e-03 2.27445756e-03 8.25348102e-05 4.39420691e-03
#  1.54006623e-03 1.23284841e-03]
# -----------
# Points within 500 meters of point 87: [], Distances: []
# -----------
# Points within 500 meters of point 88: [  4497   5735  11259 439356 510839], Distances: [0.00035697 0.00085655 0.00139974 0.00193245 0.00206668]
# Similarity score between '['renaissance montgomery spa convention center']' and '['renaissance montgomery spa convention center']': 100.0
# -----------
# Points within 500 meters of point 89: [  4284  23395  33487  43157  45752  58043  65176  78802 153444 156043
#  258450], Distances: [0.00352664 0.00141132 0.00039583 0.00186811 0.00267883 0.00079644
#  0.00223031 0.00345135 0.00368699 0.0044131  0.00247269]
# Similarity score between '['sleep montgomery i 85']' and '['sleep']': 100.0
# Similarity score between '['sleep montgomery i 85']' and '['montgomery']': 100.0
# -----------
# Points within 500 meters of point 90: [ 13637  15769  22818  34158  34720  35794 146072], Distances: [0.00246265 0.00323863 0.00423978 0.00106645 0.00178378 0.00415454
#  0.0034617 ]
# -----------
# Points within 500 meters of point 91: [  4497   5735  11259  15330 439356 510839], Distances: [2.18126317e-03 2.86342260e-03 1.34776445e-03 3.94891238e-03
#  2.81593128e-03 9.48103370e-05]
# Similarity score between '['springhill marriott montgomery downtown']' and '['springhill marriott montgomery downtown']': 100.0
# -----------
# Points within 500 meters of point 92: [  4284  23395  23761  27770  33487  38940  43157  45752  58043  65176
#   78802 153444 156043 157448 258450], Distances: [0.00286516 0.00211059 0.0035659  0.00377664 0.00292811 0.0028403
#  0.00336537 0.00191361 0.00403591 0.00393364 0.00236175 0.00236221
#  0.00372621 0.00375466 0.00334299]
# Similarity score between '['stayapt montgomery']' and '['montgomery']': 100.0
# -----------
# Points within 500 meters of point 93: [  4497   5735  11259 439356 510839], Distances: [2.26162567e-03 2.36117485e-03 1.40610051e-03 7.32574228e-05
#  2.70916346e-03]
# Similarity score between '['staybridge montgomery downtown']' and '['staybridge montgomery downtown']': 100.0
# -----------
# Points within 500 meters of point 94: [ 14314  24045  27549  27691  41672 149466], Distances: [0.00044866 0.00383675 0.00397798 0.00336538 0.00309721 0.00023737]
# Similarity score between '['comfort pelham hoover i 65']' and '['comfort']': 100.0
# -----------
# Points within 500 meters of point 95: [ 65607  71119 106866], Distances: [0.00255084 0.00093324 0.00055392]
# -----------
# Points within 500 meters of point 96: [ 14314  24045  27549  27691  41672 149466], Distances: [0.00320256 0.00129587 0.00443613 0.0022304  0.00070501 0.00325072]
# Similarity score between '['fairfield marriott birmingham pelham i 65']' and '['fairfield marriott pelham']': 100.0
# -----------
# Points within 500 meters of point 97: [ 14314  24045  27691  41672 149466], Distances: [0.00418599 0.00042934 0.00345562 0.00194598 0.00430427]
# Similarity score between '['hampton birmingham pelham i 65']' and '['hampton birminghampelham']': 88.88888888888889
# -----------
# Points within 500 meters of point 98: [ 14314  24045  27549  27691  41672 149466], Distances: [0.00385279 0.00346685 0.00247655 0.00014461 0.00151331 0.00372074]
# Similarity score between '['holiday express birmingham pelham']' and '['holiday express birmingham pelham']': 100.0
# -----------
# Points within 500 meters of point 99: [27549 40372 61878 65607], Distances: [0.00288276 0.00307304 0.00027493 0.00282027]
# Similarity score between '['quality pelham i 65 exit 246 inn']' and '['quality inn']': 100.0
# -----------
# Points within 500 meters of point 100: [40372 61878 65607], Distances: [0.00021119 0.00346472 0.00376192]
# Similarity score between '['ramada wyndham pelham']' and '['ramada pelham']': 100.0
# -----------
# Points within 500 meters of point 101: [ 27549  27691  41672  61878 149466], Distances: [0.00013327 0.0024994  0.00393969 0.00247633 0.0042794 ]
# Similarity score between '['sleep pelham oak mountain']' and '['sleep pelham']': 100.0
# -----------
# Points within 500 meters of point 102: [  7277 620622 620772 620839 621318], Distances: [0.00030639 0.00300471 0.00303342 0.00305286 0.00295596]
# -----------
# Points within 500 meters of point 103: [], Distances: []
# -----------
# Points within 500 meters of point 104: [], Distances: []
# -----------
# Points within 500 meters of point 105: [], Distances: []
# -----------
# Points within 500 meters of point 106: [ 37847 149780 620302], Distances: [0.00077207 0.00029263 0.00038642]
# -----------
# Points within 500 meters of point 107: [75796], Distances: [0.0003963]
# Similarity score between '['best western apache junction']' and '['best western apache junction inn']': 100.0
# -----------
# Points within 500 meters of point 108: [], Distances: []
# -----------
# Points within 500 meters of point 109: [32383], Distances: [0.00148097]
# Similarity score between '['hilton vacation club rancho manana resort cave creek']' and '['rancho manana resort']': 100.0
# -----------
# Points within 500 meters of point 110: [], Distances: []
# -----------
# Points within 500 meters of point 111: [40431], Distances: [0.00015134]
# Similarity score between '['best western gold canyon']' and '['best western gold canyon']': 100.0
# -----------
# Points within 500 meters of point 112: [190608], Distances: [0.00033314]
# Similarity score between '['gold canyon golf resort resort']' and '['gold canyon golf resort spa']': 100.0
# -----------
# Points within 500 meters of point 113: [454415 622021], Distances: [0.00318683 0.00042869]
# Similarity score between '['hampton tucson marana']' and '['hampton tucson marana']': 100.0
# Similarity score between '['hampton tucson marana']' and '['hampton tucson marana']': 100.0
# -----------
# Points within 500 meters of point 114: [53768 56909 59678], Distances: [0.00210629 0.00149301 0.00032157]
# Similarity score between '['best western sonora nogales']' and '['best western sonora']': 100.0
# -----------
# Points within 500 meters of point 115: [], Distances: []
# -----------
# Points within 500 meters of point 116: [], Distances: []
# -----------
# Points within 500 meters of point 117: [53768 56909 59678], Distances: [0.00131013 0.00037266 0.00112835]
# Similarity score between '['holiday express nogales']' and '['holiday express nogales']': 100.0
# -----------
# Points within 500 meters of point 118: [ 37216  59808 155359], Distances: [0.00049797 0.00097078 0.00101878]
# -----------
# Points within 500 meters of point 119: [126032], Distances: [0.00090621]
# Similarity score between '['6 nogales az mariposa road']' and '['6 nogales']': 100.0
# -----------
# Points within 500 meters of point 120: [ 37216  59808 155359], Distances: [0.00169526 0.00275311 0.00110887]
# -----------
# Points within 500 meters of point 121: [], Distances: []
# -----------
# Points within 500 meters of point 122: [31188 56093], Distances: [0.00376961 0.00183903]
# Similarity score between '['fairfield tucsono valley']' and '['fairfield tucson/oro valley']': 90.19607843137254
# -----------
# Points within 500 meters of point 123: [42977], Distances: [0.0038338]
# Similarity score between '['holiday express o valley tucson']' and '['holiday express o valley tucson']': 100.0
# -----------
# Points within 500 meters of point 124: [152465 498888], Distances: [0.00094045 0.0036673 ]
# Similarity score between '['worldmark rancho vistoso o valley']' and '['worldmark rancho vistoso']': 100.0
# -----------
# Points within 500 meters of point 125: [36456], Distances: [0.00131542]
# Similarity score between '['boulders resort spa scottsdale curio collection hilton resort']' and '['boulders resort spa curio collection hilton']': 100.0
# -----------
# Points within 500 meters of point 126: [ 23173 256172], Distances: [0.00057143 0.00068986]
# -----------
# Points within 500 meters of point 127: [127070 147584], Distances: [0.00349135 0.00056027]
# -----------
# Points within 500 meters of point 128: [], Distances: []
# -----------
# Points within 500 meters of point 129: [127070 147584], Distances: [0.00076668 0.00221547]
# -----------
# Points within 500 meters of point 130: [147584], Distances: [0.00199892]
# -----------
# Points within 500 meters of point 131: [127070 147584], Distances: [0.00107797 0.00191827]
# -----------
# Points within 500 meters of point 132: [], Distances: []
# -----------
# Points within 500 meters of point 133: [115016 118574 126685], Distances: [0.00338648 0.00334126 0.00139807]
# Similarity score between '['days wyndham willcox']' and '['days willcox']': 100.0
# Similarity score between '['days wyndham willcox']' and '['6 willcox']': 87.5
# -----------
# Points within 500 meters of point 134: [], Distances: []
# -----------
# Points within 500 meters of point 135: [], Distances: []
# -----------
# Points within 500 meters of point 136: [460642], Distances: [0.0001558]
# -----------
# Points within 500 meters of point 137: [115016 118574 126685], Distances: [0.00111849 0.00292163 0.0017707 ]
# Similarity score between '['studio 6 willcox az']' and '['6 willcox']': 100.0
# -----------
# Points within 500 meters of point 138: [108559 119065], Distances: [0.00371837 0.00014523]
# Similarity score between '['super 8 wyndham willcox']' and '['super 8 willcox az']': 90.9090909090909
# -----------
# Points within 500 meters of point 139: [115016 118574 126685], Distances: [0.00220114 0.00437944 0.00068059]
# Similarity score between '['willcox extended residence']' and '['6 willcox']': 87.5
# -----------
# Points within 500 meters of point 140: [], Distances: []
# -----------
# Points within 500 meters of point 141: [67728], Distances: [0.00062126]
# -----------
# Points within 500 meters of point 142: [], Distances: []
# -----------
# Points within 500 meters of point 143: [  9597  15456  16476  21564  29675  32621  47477 149985 151109 254913], Distances: [0.00121399 0.00083227 0.00226954 0.002617   0.0038489  0.00111256
#  0.00359454 0.00207023 0.00053163 0.00345371]
# Similarity score between '['comfort bryant benton']' and '['comfort bryant']': 100.0
# Similarity score between '['comfort bryant benton']' and '['comfort']': 100.0
# -----------
# Points within 500 meters of point 144: [  9597  15456  16476  21564  29675  32621  47477 151109 254913], Distances: [0.00404068 0.00259949 0.00383078 0.00246115 0.00059854 0.00399499
#  0.00045188 0.00325293 0.00024082]
# Similarity score between '['country radisson bryant little rock ar']' and '['country']': 100.0
# -----------
# Points within 500 meters of point 145: [  9597  15456  16476  21564  29675  32621  47477 149985 151109 254913], Distances: [0.00177907 0.00165735 0.00306262 0.00348147 0.00443358 0.00167168
#  0.00408004 0.00261119 0.00060313 0.00397138]
# -----------
# Points within 500 meters of point 146: [  9597  15456  16476  21564  32621 149985 151109], Distances: [0.00046167 0.00187667 0.00130754 0.00263944 0.00056549 0.00040602
#  0.00218118]
# Similarity score between '['la quinta wyndham little rock bryant']' and '['la quinta bryant']': 100.0
# -----------
# Points within 500 meters of point 147: [  6566  37055  68824 619886 619887], Distances: [0.00294427 0.0022536  0.00178008 0.00167172 0.00167028]
# Similarity score between '['americas best value cabot']' and '['americas best value inn']': 90.47619047619048
# -----------
# Points within 500 meters of point 148: [  6566  68824 619886 619887], Distances: [0.00036568 0.0015447  0.00160932 0.00161134]
# Similarity score between '['days wyndham cabot']' and '['days cabot']': 100.0
# -----------
# Points within 500 meters of point 149: [], Distances: []
# -----------
# Points within 500 meters of point 150: [ 68824 619886 619887], Distances: [0.00357157 0.00386705 0.00387007]
# -----------
# Points within 500 meters of point 151: [  6566  37055  68824 619886 619887], Distances: [0.00168033 0.00389654 0.00048873 0.00082496 0.00082887]
# Similarity score between '['super 8 wyndham cabot']' and '['super 8 cabot']': 100.0
# -----------
# Points within 500 meters of point 152: [ 73061  76309  78272  82463 201538 270071 270072 346293], Distances: [0.00342515 0.00176953 0.00316281 0.00313567 0.00221172 0.00420833
#  0.00265038 0.0017065 ]
# Similarity score between '['1886 crescent spa eureka springs']' and '['1886 crescent spa']': 100.0
# -----------
# Points within 500 meters of point 153: [ 73061  76442  82463 155006 156612 270072 285955 288424], Distances: [0.0026519  0.00020073 0.0040386  0.00432311 0.00087    0.00353381
#  0.00124109 0.00311256]
# Similarity score between '['1905 basin park eureka springs']' and '['basin park']': 100.0
# -----------
# Points within 500 meters of point 154: [ 78272 201538 260514 270071 346293 392760], Distances: [0.00032189 0.00122304 0.00245559 0.00121112 0.00303229 0.00228532]
# -----------
# Points within 500 meters of point 155: [ 77680  81125 100233 102074 103246 176111 213337], Distances: [4.20393268e-03 3.34607980e-03 1.98127484e-03 4.14550962e-03
#  9.82344135e-05 2.30830024e-03 3.33755150e-03]
# Similarity score between '['best western of ozarks eureka springs']' and '['best western of ozarks']': 100.0
# -----------
# Points within 500 meters of point 156: [ 88567 148616], Distances: [0.00186802 0.00100329]
# -----------
# Points within 500 meters of point 157: [ 72933  83119  84320  87313  99166 152187 158361], Distances: [0.00112026 0.00231962 0.00126308 0.0019111  0.00145044 0.00046547
#  0.00318836]
# -----------
# Points within 500 meters of point 158: [542833 556595 622363], Distances: [6.40312424e-06 1.52634236e-03 3.03482856e-03]
# Similarity score between '['evening shade eureka springs']' and '['evening shade inn']': 86.66666666666667
# -----------
# Points within 500 meters of point 159: [ 73061  76442 156612 270072 285955 288424], Distances: [0.0029297  0.00110655 0.00019277 0.00356006 0.00098196 0.00384081]
# Similarity score between '['grand central eureka springs']' and '['grand central spa']': 86.66666666666667
# -----------
# Points within 500 meters of point 160: [79531], Distances: [0.00026566]
# -----------
# Points within 500 meters of point 161: [ 72867  77680  81125 100233 102074 103246 147719 176111 213337], Distances: [0.00408066 0.00331025 0.00241141 0.00107979 0.00370319 0.00127415
#  0.00438985 0.00143809 0.00243758]
# -----------
# Points within 500 meters of point 162: [ 92589 102074 147719 584226 624213], Distances: [0.00282116 0.00100541 0.0004416  0.00061992 0.00268357]
# -----------
# Points within 500 meters of point 163: [ 73061  76442  82463 155006 156612 270072 285955 288424], Distances: [0.00153085 0.00145245 0.00327174 0.00408003 0.00120615 0.00226445
#  0.00226634 0.00426616]
# -----------
# Points within 500 meters of point 164: [ 92589 102074 147719 584226 624213], Distances: [0.00053775 0.00406669 0.00344925 0.00244863 0.00039418]
# Similarity score between '['osage creek lodge eureka springs']' and '['osage creek lodge']': 100.0
# -----------
# Points within 500 meters of point 165: [ 72933  83119  84320  87313  99166 152187 158361], Distances: [8.28070045e-04 1.51608047e-03 8.87524648e-04 3.15293514e-03
#  1.00000000e-04 1.59260792e-03 4.38823213e-03]
# Similarity score between '['quality eureka springs']' and '['quality eureka springs']': 100.0
# -----------
# Points within 500 meters of point 166: [ 72867  75196  77680  81125 100233 103246 176111 213337 254184 498600], Distances: [0.00321155 0.0042065  0.00262632 0.00237022 0.00234563 0.00304718
#  0.00218387 0.00227089 0.00339817 0.0044299 ]
# -----------
# Points within 500 meters of point 167: [ 79992  80425  81733 103583 153681 256561 622363], Distances: [0.00351597 0.00021379 0.00155393 0.00263933 0.00153073 0.00040187
#  0.0034114 ]
# Similarity score between '['super 8 wyndham eureka springs']' and '['eureka']': 100.0
# -----------
# Points within 500 meters of point 168: [ 78297 254184 519406], Distances: [0.00173093 0.00227504 0.00101871]
# -----------
# Points within 500 meters of point 169: [ 72933  83119  84320  87313  99166 152187 158361], Distances: [0.00028695 0.00260305 0.0002819  0.003022   0.00118546 0.00102254
#  0.00430227]
# -----------
# Points within 500 meters of point 170: [ 76442 156612 285955 288424], Distances: [0.00330534 0.00380439 0.00272073 0.00219733]
# -----------
# Points within 500 meters of point 171: [], Distances: []
# -----------
# Points within 500 meters of point 172: [], Distances: []
# -----------
# Points within 500 meters of point 173: [ 2336 11067 15719 26548 58091 66270], Distances: [0.00093833 0.00035323 0.00216989 0.00328584 0.0006323  0.00079655]
# -----------
# Points within 500 meters of point 174: [ 28831  34770  42968 146105 146106 146107 146673], Distances: [0.00406908 0.00356709 0.00274068 0.00334408 0.00334408 0.00334408
#  0.00305188]
# Similarity score between '['best western windsor fayetteville']' and '['best western windsor']': 100.0
# -----------
# Points within 500 meters of point 175: [ 28831  34770 146105 146106 146107 146451 146673], Distances: [0.00160765 0.00361934 0.00300908 0.00300908 0.00300908 0.00012107
#  0.00327039]
# Similarity score between '['candlewood fayetteville']' and '['candlewood fayetteville â€“ university of arkansas']': 100.0
# Similarity score between '['candlewood fayetteville']' and '['candlewood fayetteville ar']': 100.0
# -----------
# Points within 500 meters of point 176: [  2233   8706  15806 122003], Distances: [0.00067036 0.00305241 0.00048629 0.00315667]
# Similarity score between '['comfort fayetteville university']' and '['comfort fayetteville']': 100.0
# -----------
# Points within 500 meters of point 177: [  6282   7298  48467 469748], Distances: [0.00094312 0.00371581 0.0035818  0.00249709]
# Similarity score between '['courtyard marriott fayetteville']' and '['courtyard marriott fayetteville']': 100.0
# Similarity score between '['courtyard marriott fayetteville']' and '['fayetteville']': 100.0
# -----------
# Points within 500 meters of point 178: [ 2336 11067 15719 58091 66270], Distances: [0.00312513 0.00243818 0.0006046  0.0017661  0.00165248]
# Similarity score between '['days wyndham fayetteville']' and '['days fayetteville']': 100.0
# -----------
# Points within 500 meters of point 179: [], Distances: []
# -----------
# Points within 500 meters of point 180: [620753], Distances: [0.00449314]
# -----------
# Points within 500 meters of point 181: [ 2336 11067 15719 26548 58091 66270], Distances: [0.00182025 0.001298   0.00147092 0.00424129 0.00044011 0.00085586]
# -----------
# Points within 500 meters of point 182: [  6282   7298  48467 469748], Distances: [0.00358583 0.00426387 0.00427553 0.00017603]
# Similarity score between '['fairfield marriott fayetteville']' and '['fayetteville']': 100.0
# Similarity score between '['fairfield marriott fayetteville']' and '['fairfield marriott fayetteville']': 100.0
# -----------
# Points within 500 meters of point 183: [  5385 620753], Distances: [0.00017482 0.0001901 ]
# Similarity score between '['graduate hilton fayetteville']' and '['the graduate fayetteville']': 91.30434782608695
# -----------
# Points within 500 meters of point 184: [ 2336 11067 15719 26548 58091 66270], Distances: [0.00120548 0.00193081 0.0035781  0.00292184 0.00173739 0.00246495]
# Similarity score between '['hampton fayetteville']' and '['hampton fayetteville']': 100.0
# -----------
# Points within 500 meters of point 185: [  2233   8706  15806 122003], Distances: [0.00151507 0.00218335 0.00143773 0.00229709]
# Similarity score between '['hilton garden fayetteville convention center']' and '['hilton garden fayetteville']': 100.0
# -----------
# Points within 500 meters of point 186: [  2233   8706  15806 122003], Distances: [0.0031074  0.00062379 0.00299902 0.00074416]
# Similarity score between '['holiday express fayetteville university of arkansas']' and '['holiday express fayetteville univ of ar']': 88.57142857142857
# -----------
# Points within 500 meters of point 187: [  2233   8706  15806 122003], Distances: [0.00167384 0.0020412  0.00151086 0.00214166]
# Similarity score between '['homewood hilton fayetteville']' and '['homewood hilton fayetteville']': 100.0
# -----------
# Points within 500 meters of point 188: [6282], Distances: [0.00209879]
# -----------
# Points within 500 meters of point 189: [195649], Distances: [0.00033467]
# Similarity score between '['at carnall hall fayetteville']' and '['at carnall hall']': 100.0
# -----------
# Points within 500 meters of point 190: [ 2763 25013], Distances: [0.00221475 0.00196882]
# Similarity score between '['at mill ascend collection fayetteville']' and '['at mill ascend collection member']': 87.71929824561403
# -----------
# Points within 500 meters of point 191: [  6282   7298  48467 469748], Distances: [0.00392166 0.00044001 0.00050646 0.00370387]
# Similarity score between '['la quinta wyndham fayetteville']' and '['fayetteville']': 100.0
# -----------
# Points within 500 meters of point 192: [116300], Distances: [0.00032863]
# Similarity score between '['6 fayetteville ar']' and '['6 fayetteville ar']': 100.0
# -----------
# Points within 500 meters of point 193: [ 2336 11067 15719 26548 58091 66270], Distances: [0.00195927 0.00120069 0.00114779 0.0042989  0.00076876 0.00044828]
# Similarity score between '['regency 7 fayettevill']' and '['regency 7']': 100.0
# -----------
# Points within 500 meters of point 194: [  6282   7298  48467 469748], Distances: [0.003787   0.00101774 0.00108862 0.0031557 ]
# Similarity score between '['sleep fayetteville']' and '['fayetteville']': 100.0
# -----------
# Points within 500 meters of point 195: [ 16686 611495], Distances: [0.00204415 0.00231707]
# Similarity score between '['staybridge fayetteville']' and '['staybridge fayetteville/univ of arkansas']': 100.0
# -----------
# Points within 500 meters of point 196: [  2336  11067  26548  34770  42968  58091  66270 146105 146106 146107
#  146673], Distances: [0.00262264 0.00345641 0.00085731 0.00319132 0.00364353 0.00398096
#  0.00430118 0.00382979 0.00382979 0.00382979 0.00388651]
# Similarity score between '['super 8 wyndham fayetteville']' and '['super 8 fayetteville']': 100.0
# -----------
# Points within 500 meters of point 197: [107906], Distances: [0.00151659]
# Similarity score between '['holiday express heber springs']' and '['holiday express heber springs']': 100.0
# -----------
# Points within 500 meters of point 198: [274943], Distances: [0.00088866]
# Similarity score between '['oyo heber springs lakeside']' and '['heber springs lakeside']': 100.0
# -----------
# Points within 500 meters of point 199: [110600], Distances: [0.00056419]
# Similarity score between '['quality conference center heber springs']' and '['quality heber springs']': 100.0
# -----------
# Points within 500 meters of point 200: [26986], Distances: [0.00038133]
# -----------
# Points within 500 meters of point 201: [21809 26691 29648 44835 70900], Distances: [0.00050357 0.00225204 0.00050222 0.00305259 0.00046037]
# -----------
# Points within 500 meters of point 202: [ 2763 25013], Distances: [0.00241451 0.00196993]
# Similarity score between '['towneplace marriott fayetteville n springdale johnson']' and '['towneplace marriott fayetteville']': 100.0
# -----------
# Points within 500 meters of point 203: [ 13742  50111 620580], Distances: [0.00044797 0.00166951 0.00079372]
# Similarity score between '['la quinta wyndham fort smith massard']' and '['la quinta fort smith']': 100.0
# -----------
# Points within 500 meters of point 204: [], Distances: []
# -----------
# Points within 500 meters of point 205: [130272 621978], Distances: [0.00024774 0.00066617]
# -----------
# Points within 500 meters of point 206: [258420 277485], Distances: [0.00044909 0.00054616]
# Similarity score between '['cottonwood salem']' and '['cottonwood salem ar']': 100.0
# -----------
# Points within 500 meters of point 207: [  9137  14324  16896  16942  21467  28923 430350 620394 621372], Distances: [0.0003717  0.00438782 0.0043658  0.00315497 0.00124532 0.00156348
#  0.00292478 0.00284626 0.00369752]
# Similarity score between '['doubletree hilton springdale']' and '['doubletree club hilton springdale']': 100.0
# -----------
# ...
# -----------
# Points within 500 meters of point 4846: [ 48803 158822 247410], Distances: [0.00108158 0.0026434  0.0024825 ]
# Similarity score between '['grandstay residential eau claire']' and '['grandstay residential eau claire']': 100.0
# -----------
# Points within 500 meters of point 4847: [152810], Distances: [0.00313081]
# Similarity score between '['sleep milwaukee franklin']' and '['hampton milwaukee / franklin']': 85.71428571428571
# -----------
# Points within 500 meters of point 4848: [], Distances: []
# -----------
# Points within 500 meters of point 4849: [14500 50852], Distances: [0.00315305 0.00335021]
# Similarity score between '['best western germantown']' and '['best western germantown inn']': 100.0
# -----------
# Points within 500 meters of point 4850: [30595 35044], Distances: [0.00047901 0.0020767 ]
# -----------
# Points within 500 meters of point 4851: [], Distances: []
# -----------
# Points within 500 meters of point 4852: [154735], Distances: [0.00052162]
# -----------
# Points within 500 meters of point 4853: [], Distances: []
# -----------
# Points within 500 meters of point 4854: [], Distances: []
# -----------
# Points within 500 meters of point 4855: [ 64677 525062], Distances: [0.00054598 0.00412006]
# Similarity score between '['harbor lights lodge kewaune']' and '['harbor lights lodge']': 100.0
# -----------
# Points within 500 meters of point 4856: [   890   5204   8157  18301  39443  78903 156991 620720], Distances: [0.00348706 0.00395157 0.0031653  0.00071943 0.00044021 0.00021444
#  0.00127965 0.00054977]
# Similarity score between '['americby wyndham la crosse riverfront conference center']' and '['americ la crosse riverfront']': 85.1063829787234
# -----------
# Points within 500 meters of point 4857: [ 36426 148255], Distances: [0.00043352 0.00022125]
# Similarity score between '['candlewood la crosse']' and '['candlewood la crosse n']': 100.0
# -----------
# Points within 500 meters of point 4858: [   890   5204  18301  39443  78903 620720], Distances: [0.00114573 0.00104453 0.00412408 0.00363326 0.00410667 0.00348737]
# Similarity score between '['country radisson la crosse wi']' and '['6 la crosse wi']': 92.3076923076923
# -----------
# Points within 500 meters of point 4859: [   890   5204   8157  18301  39443  78903 156991 620720], Distances: [2.97397107e-03 3.43727554e-03 3.61488555e-03 9.28867237e-04
#  1.81180418e-04 6.35402820e-04 1.62159919e-03 4.54499552e-05]
# Similarity score between '['econo lodge lodge la cross']' and '['econo lodge la crosse']': 97.5609756097561
# -----------
# Points within 500 meters of point 4860: [   664   2683   5754 153092 155901 254503 258393 623376 623713], Distances: [0.00345347 0.00315013 0.00447715 0.00183118 0.00041881 0.00334813
#  0.00447597 0.00029952 0.00148517]
# Similarity score between '['fairfield marriott la crosse downtown']' and '['fairfield marriott la crosse downtown']': 100.0
# Similarity score between '['fairfield marriott la crosse downtown']' and '['fairfield marriott la crosse']': 100.0
# -----------
# Points within 500 meters of point 4861: [], Distances: []
# -----------
# Points within 500 meters of point 4862: [165596 623344], Distances: [0.00026385 0.00047627]
# Similarity score between '['gundersen la cross']' and '['gundersen']': 100.0
# Similarity score between '['gundersen la cross']' and '['gundersen']': 100.0
# -----------
# Points within 500 meters of point 4863: [  7483 148747 153871 622813], Distances: [0.0034111  0.00122872 0.00046107 0.00140977]
# Similarity score between '['hampton la crosse downtown']' and '['hampton']': 100.0
# Similarity score between '['hampton la crosse downtown']' and '['hampton la crosse downtown']': 100.0
# Similarity score between '['hampton la crosse downtown']' and '['hampton downtown la crosse']': 100.0
# -----------
# Points within 500 meters of point 4864: [   890   5204  18301  39443  78903 620720], Distances: [0.00102311 0.00096244 0.00401354 0.00350658 0.0039862  0.00336376]
# Similarity score between '['6 la crosse wi']' and '['6 la crosse wi']': 100.0
# -----------
# Points within 500 meters of point 4865: [   890   5204  39443 620720], Distances: [0.00144104 0.00103282 0.00438788 0.00426918]
# -----------
# Points within 500 meters of point 4866: [ 11748 158765], Distances: [0.000684   0.00046534]
# -----------
# Points within 500 meters of point 4867: [   664   2683   5754 117495 153092 258393 619581 623713], Distances: [0.00398481 0.00184918 0.00058575 0.00195759 0.00308468 0.00041917
#  0.00231512 0.00331735]
# Similarity score between '['radisson la crosse']' and '['radisson la crosse']': 100.0
# -----------
# Points within 500 meters of point 4868: [  8157  18301  39443  78903 156991 620720], Distances: [0.00026023 0.00252228 0.00333453 0.00273552 0.00320436 0.00335881]
# Similarity score between '['super 8 wyndham la crosse']' and '['super 8 la crosse']': 100.0
# -----------
# Points within 500 meters of point 4869: [], Distances: []
# -----------
# Points within 500 meters of point 4870: [  566  5925 12364], Distances: [0.00129581 0.00121367 0.00074524]
# Similarity score between '['bella vista lake geneva']' and '['bella vista']': 100.0
# -----------
# Points within 500 meters of point 4871: [  566  5925 12364], Distances: [0.0001886  0.00043658 0.00062939]
# Similarity score between '['the cove of lake geneva resort']' and '['the cove of lake geneva']': 100.0
# -----------
# Points within 500 meters of point 4872: [259057], Distances: [0.00017932]
# -----------
# Points within 500 meters of point 4873: [], Distances: []
# -----------
# Points within 500 meters of point 4874: [], Distances: []
# -----------
# Points within 500 meters of point 4875: [], Distances: []
# -----------
# Points within 500 meters of point 4876: [ 315 6963], Distances: [0.00169564 0.00103519]
# -----------
# Points within 500 meters of point 4877: [6132], Distances: [0.00029234]
# Similarity score between '['baymont wyndham marshfield']' and '['baymont']': 100.0
# -----------
# Points within 500 meters of point 4878: [], Distances: []
# -----------
# Points within 500 meters of point 4879: [121578 256618 256635], Distances: [0.0014191  0.00058794 0.00074249]
# Similarity score between '['marshfield bw premier collection']' and '['marshfield']': 100.0
# Similarity score between '['marshfield bw premier collection']' and '['marshfield']': 100.0
# Similarity score between '['marshfield bw premier collection']' and '['marshfield']': 100.0
# -----------
# Points within 500 meters of point 4880: [ 315 6963], Distances: [0.00167236 0.00325098]
# Similarity score between '['woodfield marshfield']' and '['woodfield']': 100.0
# -----------
# Points within 500 meters of point 4881: [ 25530  38323  69835 256750], Distances: [0.00164535 0.00015984 0.00152243 0.00218062]
# -----------
# Points within 500 meters of point 4882: [], Distances: []
# -----------
# Points within 500 meters of point 4883: [], Distances: []
# -----------
# Points within 500 meters of point 4884: [ 81161 259584 358455], Distances: [0.0005515  0.00324224 0.00302632]
# -----------
# Points within 500 meters of point 4885: [  6928   7693   8599  23047  32975 153432 180163 621115 622201 624389], Distances: [0.00113688 0.00074254 0.00268199 0.00190025 0.00277003 0.00352872
#  0.00410648 0.00335234 0.00017237 0.00182988]
# Similarity score between '['the pfister milwaukee']' and '['the pfister']': 100.0
# Similarity score between '['the pfister milwaukee']' and '['pfister milwaukee']': 100.0
# -----------
# Points within 500 meters of point 4886: [], Distances: []
# -----------
# Points within 500 meters of point 4887: [28695], Distances: [0.00132637]
# Similarity score between '['best western premier bridgewood resort neena']' and '['best western premier bridgewood resort']': 100.0
# -----------
# Points within 500 meters of point 4888: [258288 421538], Distances: [0.00170355 0.00095894]
# Similarity score between '['cobblestone appleton international airport neena']' and '['cobblestone']': 100.0
# Similarity score between '['cobblestone appleton international airport neena']' and '['cobblestone appleton international airport']': 100.0
# -----------
# Points within 500 meters of point 4889: [3654], Distances: [0.00105544]
# -----------
# Points within 500 meters of point 4890: [], Distances: []
# -----------
# Points within 500 meters of point 4891: [], Distances: []
# -----------
# Points within 500 meters of point 4892: [ 60981 284094], Distances: [0.00423631 0.00433114]
# -----------
# Points within 500 meters of point 4893: [40652], Distances: [0.0013166]
# Similarity score between '['la quinta wyndham milwaukee airport oak creek']' and '['la quinta milwaukee airport/oak creek']': 100.0
# -----------
# Points within 500 meters of point 4894: [6832], Distances: [0.00192438]
# Similarity score between '['baymont wyndham la crosse onalaska']' and '['microtel wyndham onalaska/la crosse']': 86.95652173913044
# -----------
# Points within 500 meters of point 4895: [8402], Distances: [0.00161237]
# Similarity score between '['comfort onalaska la crosse inn']' and '['comfort onalaska']': 100.0
# -----------
# Points within 500 meters of point 4896: [4687], Distances: [0.0009827]
# -----------
# Points within 500 meters of point 4897: [620880], Distances: [0.00043673]
# Similarity score between '['holiday express onalaska la crosse']' and '['holiday express']': 100.0
# -----------
# Points within 500 meters of point 4898: [6832], Distances: [0.00089031]
# Similarity score between '['microtel la crosse onalaska']' and '['microtel wyndham onalaska/la crosse']': 100.0
# -----------
# Points within 500 meters of point 4899: [65384], Distances: [0.00080655]
# Similarity score between '['rainbow ridge farms onalaska']' and '['rainbow ridge farms']': 100.0
# -----------
# Points within 500 meters of point 4900: [21331], Distances: [0.00273218]
# -----------
# Points within 500 meters of point 4901: [   164 623862], Distances: [0.001547   0.00068522]
# Similarity score between '['stoney creek la crosse onalaska']' and '['stoney creek la crosse onalaska']': 100.0
# -----------
# Points within 500 meters of point 4902: [], Distances: []
# -----------
# Points within 500 meters of point 4903: [], Distances: []
# -----------
# Points within 500 meters of point 4904: [2266], Distances: [0.00070024]
# -----------
# Points within 500 meters of point 4905: [], Distances: []
# -----------
# Points within 500 meters of point 4906: [ 16097 109772 254428], Distances: [0.00168302 0.0016766  0.00087069]
# -----------
# Points within 500 meters of point 4907: [8118], Distances: [0.00102973]
# Similarity score between '['boarders cobblestone s ripon']' and '['boarders ripon']': 100.0
# -----------
# Points within 500 meters of point 4908: [5193 8118], Distances: [0.00235328 0.00297934]
# -----------
# Points within 500 meters of point 4909: [137188], Distances: [0.00272482]
# -----------
# Points within 500 meters of point 4910: [258446 374753], Distances: [0.00071688 0.00159284]
# Similarity score between '['hilton garden madison sun prairie']' and '['hilton garden madison sun prairie']': 100.0
# Similarity score between '['hilton garden madison sun prairie']' and '['hilton garden sun prairie madison']': 100.0
# -----------
# Points within 500 meters of point 4911: [103271], Distances: [0.00073969]
# Similarity score between '['quality sun prairie madison']' and '['quality']': 100.0
# -----------
# Points within 500 meters of point 4912: [ 13929  27786  28005 147680], Distances: [0.00064309 0.00343451 0.00094443 0.00075796]
# Similarity score between '['cranberry country lodge tomah']' and '['cranberry country lodge']': 100.0
# -----------
# Points within 500 meters of point 4913: [], Distances: []
# -----------
# Points within 500 meters of point 4914: [29025 30556 39032], Distances: [0.00039395 0.00404787 0.00035912]
# Similarity score between '['extended stay america select milwaukee wauwatosa']' and '['extended stay america milwaukee wauwatosa']': 100.0
# -----------
# Points within 500 meters of point 4915: [29025 30556 39032], Distances: [1.62745424e-04 3.84338883e-03 6.06619568e-05]
# -----------
# Points within 500 meters of point 4916: [294314], Distances: [0.00162678]
# Similarity score between '['homewood hilton wauwatosa milwaukee']' and '['homewood hilton wauwatosa milwaukee']': 100.0
# -----------
# Points within 500 meters of point 4917: [ 30556 624715], Distances: [0.00125021 0.00016553]
# Similarity score between '['renaissance milwaukee wauwatosa']' and '['renaissance milwaukee']': 100.0
# -----------
# Points within 500 meters of point 4918: [153880], Distances: [0.00089274]
# Similarity score between '['residence marriott milwaukee wauwatosa']' and '['residence milwaukee west']': 88.37209302325581
# -----------
# Points within 500 meters of point 4919: [ 14099 463245 623404], Distances: [0.00276344 0.00309913 0.00344633]
# -----------
# Points within 500 meters of point 4920: [ 14099 463245 623404], Distances: [0.0007362  0.0006318  0.00028638]
# Similarity score between '['springhill marriott milwaukee wauwatosa']' and '['springhill marriott milwaukee west/wauwatosa']': 100.0
# Similarity score between '['springhill marriott milwaukee wauwatosa']' and '['springhill marriott milwaukee west/wauwatosa']': 100.0
# -----------
# Points within 500 meters of point 4921: [106541], Distances: [0.00082701]
# Similarity score between '['hampton milwaukee allis']' and '['hampton milwaukee west']': 87.17948717948718
# -----------
# Points within 500 meters of point 4922: [19406], Distances: [0.00071622]
# Similarity score between '['hampton bend']' and '['hampton bend']': 100.0
# -----------
# Points within 500 meters of point 4923: [293693], Distances: [0.00098148]
# Similarity score between '['hidden serenity ben']' and '['hidden serenity']': 100.0
# -----------
# Points within 500 meters of point 4924: [], Distances: []
# -----------
# Points within 500 meters of point 4925: [257766 271844], Distances: [0.00049868 0.00014339]
# Similarity score between '['americby wyndham salem']' and '['americby wyndham salem']': 100.0
# -----------
# Points within 500 meters of point 4926: [], Distances: []
# -----------
# Points within 500 meters of point 4927: [], Distances: []
# -----------
# Points within 500 meters of point 4928: [], Distances: []
# -----------
# Points within 500 meters of point 4929: [92217], Distances: [0.00276987]
# Similarity score between '['jenny lake lodge lodge beaver creek']' and '['jenny lake lodge']': 100.0
# -----------
# Points within 500 meters of point 4930: [], Distances: []
# -----------
# Points within 500 meters of point 4931: [], Distances: []
# -----------
# Points within 500 meters of point 4932: [ 64899 147872 279571], Distances: [0.00039083 0.00010611 0.00389348]
# Similarity score between '['best western devils tower hulet']' and '['best western devils tower inn']': 92.5925925925926
# -----------
# Points within 500 meters of point 4933: [353262], Distances: [0.00191068]
# Similarity score between '['buffalo valley ranch luxury tent moran']' and '['buffalo valley ranch']': 100.0
# -----------
# Points within 500 meters of point 4934: [95606], Distances: [0.0038849]
# Similarity score between '['headwaters lodge cabins flagg ranch lodge moran']' and '["headwater's lodge cabins flagg ranch"]': 90.9090909090909
# -----------
# Points within 500 meters of point 4935: [353262], Distances: [0.00070971]
# -----------
# Points within 500 meters of point 4936: [146621], Distances: [0.00152779]
# Similarity score between '['jackson lake lodge lodge moran']' and '['jackson lake lodge wyoming']': 85.71428571428571
# -----------
# Points within 500 meters of point 4937: [], Distances: []
# -----------
# Points within 500 meters of point 4938: [], Distances: []
# -----------
# Points within 500 meters of point 4939: [105733], Distances: [0.00029924]
# Similarity score between '['togwotee mountain lodge lodge moran']' and '['togwotee mountain lodge']': 100.0
# -----------
# Points within 500 meters of point 4940: [127252 155484 460643], Distances: [0.00251326 0.00205864 0.00039221]
# Similarity score between '['cobblestone torrington']' and '['cobblestone torrington']': 100.0
# -----------
# Points within 500 meters of point 4941: [], Distances: []
# -----------
# Points within 500 meters of point 4942: [127252 155484 460643], Distances: [0.00062706 0.0006764  0.00227317]
# -----------

# %%
# Ensure closest_indices and closest_distances have the same length as num_small
#num_small = 252
'''if len(closest_indices) != num_small or len(closest_distances) != num_small:
    print("Error: Length mismatch between closest_indices/closest_distances and num_small.")
    print(f"Expected length: {num_small}, closest_indices length: {len(closest_indices)}, closest_distances length: {len(closest_distances)}")
    raise ValueError("Mismatch in lengths between closest_indices/closest_distances and num_small.")'''

# Initialize the dictionary to store matches
matches = {}

# Define the similarity score threshold for a match
similarity_threshold = 100


# Loop through each point in the smaller dataset (bookingData)
for i in range(num_small):
    # Safety check in case of indexing issues
    if i >= len(closest_indices) or i >= len(closest_distances):
        print(f"Skipping index {i} due to out-of-range access.")
        continue

    booking_hotel_name = str(hotel_name_small[i][0])  # Get the booking hotel name as a string

    # Check if there are matches within the threshold for this booking hotel
    if len(closest_indices[i]) == 0:
        continue

    # List to hold matches for the current booking hotel
    matched_hotels = []

    # Iterate over each matching traffic hotel within the distance threshold
    for j, idx in enumerate(closest_indices[i]):
        similarity_score = similarity_scores[i][j]
        
        # Only add matches that meet or exceed the similarity threshold
        if similarity_score >= similarity_threshold:
            # Prepare match details
            traffic_hotel_name = str(hotel_name_large[idx][0])  # Traffic hotel name as string
            lat, lon = latlon_large[idx]  # Traffic hotel coordinates
            dist = closest_distances[i][j]  # Distance to booking hotel

            # Append the match details to the list
            matched_hotels.append({
                "traffic_hotel_name": traffic_hotel_name,
                "latitude": lat,
                "longitude": lon,
                "similarity_score": similarity_score,
                "distance": dist
            })

    # Only add the booking hotel to the dictionary if there are matches
    if matched_hotels:
        matches[booking_hotel_name] = matched_hotels

matched_booking_hotels = []
# Print out the first few matches for inspection
for booking_hotel, traffic_matches in list(matches.items())[:100]:
    print(f"Booking Hotel: {booking_hotel}")
    for match in traffic_matches:
        print(f"  Matched Traffic Hotel: {match['traffic_hotel_name']}, "
              f"Latitude: {match['latitude']}, Longitude: {match['longitude']}, "
              f"Score: {match['similarity_score']}, Distance: {match['distance']}")
    matched_booking_hotels.append(booking_hotel)
    print("-----")

print(len(matches))
# Out:
# Booking Hotel: candlewood alabaster
#   Matched Traffic Hotel: candlewood alabaster, Latitude: 33.2329, Longitude: -86.80002, Score: 100.0, Distance: 0.0007507592756763593
#   Matched Traffic Hotel: candlewood alabaster alabama, Latitude: 33.2329592, Longitude: -86.7993574, Score: 100.0, Distance: 0.00013271018801404001
# -----
# Booking Hotel: microtel wyndham albertville
#   Matched Traffic Hotel: microtel wyndham albertville, Latitude: 34.27784, Longitude: -86.20232, Score: 100.0, Distance: 0.001346336758240169
# -----
# Booking Hotel: econo lodge boaz
#   Matched Traffic Hotel: econo lodge, Latitude: 34.19772, Longitude: -86.15006, Score: 100.0, Distance: 0.001093845053010089
# -----
# Booking Hotel: key boaz
#   Matched Traffic Hotel: key boaz al, Latitude: 34.19852, Longitude: -86.15788, Score: 100.0, Distance: 0.0003899357941533613
# -----
# Booking Hotel: hampton calera
#   Matched Traffic Hotel: hampton calera, Latitude: 33.14882, Longitude: -86.75135, Score: 100.0, Distance: 0.0019757490054410974
#   Matched Traffic Hotel: hampton calera, Latitude: 33.1483567, Longitude: -86.7512413, Score: 100.0, Distance: 0.0017740812964770205
# -----
# Booking Hotel: comfort cullman i 65 exit 310
#   Matched Traffic Hotel: comfort cullman, Latitude: 34.20817, Longitude: -86.87331, Score: 100.0, Distance: 0.0004573251644116745
# -----
# Booking Hotel: hampton cullman
#   Matched Traffic Hotel: hampton cullman, Latitude: 34.20868, Longitude: -86.87718, Score: 100.0, Distance: 0.004362723644321351
# -----
# Booking Hotel: la quinta wyndham cullman
#   Matched Traffic Hotel: la quinta cullman, Latitude: 34.20803, Longitude: -86.87333, Score: 100.0, Distance: 0.0038238517230692404
# -----
# Booking Hotel: quality cullman i 65 exit 310 inn
#   Matched Traffic Hotel: quality cullman, Latitude: 34.20697, Longitude: -86.87442, Score: 100.0, Distance: 0.0013352165682020223
# -----
# Booking Hotel: sleep cullman i 65 exit 310
#   Matched Traffic Hotel: sleep cullman, Latitude: 34.20843, Longitude: -86.87518, Score: 100.0, Distance: 0.00044773119167829914
# -----
# Booking Hotel: econo lodge fort payne
#   Matched Traffic Hotel: econo lodge fort payne, Latitude: 34.43711, Longitude: -85.75175, Score: 100.0, Distance: 8.266727102837532e-05
# -----
# Booking Hotel: hampton guntersville
#   Matched Traffic Hotel: hampton guntersville, Latitude: 34.32355, Longitude: -86.31428, Score: 100.0, Distance: 0.0006798021444469339
# -----
# Booking Hotel: wyndham garden lake guntersville
#   Matched Traffic Hotel: wyndham garden lake guntersville, Latitude: 34.33515, Longitude: -86.31453, Score: 100.0, Distance: 0.00045497197727612036
# -----
# Booking Hotel: courtyard birmingham hoover
#   Matched Traffic Hotel: courtyard marriott birmingham hoover, Latitude: 33.37402, Longitude: -86.803, Score: 100.0, Distance: 0.0002007283061713018
# -----
# Booking Hotel: embassy hilton birmingham hoover
#   Matched Traffic Hotel: embassy birmingham/hoover, Latitude: 33.37007, Longitude: -86.81662, Score: 100.0, Distance: 0.0007090102950550345
#   Matched Traffic Hotel: embassy, Latitude: 33.36925356136978, Longitude: -86.8162386741977, Score: 100.0, Distance: 0.00022176810567701985
# -----
# Booking Hotel: hampton birmingham hoover galleria
#   Matched Traffic Hotel: hampton birmingham hoover, Latitude: 33.37162, Longitude: -86.81196, Score: 100.0, Distance: 0.0008427386770463245
# -----
# Booking Hotel: holiday birmingham hoover
#   Matched Traffic Hotel: holiday birmingham hoover, Latitude: 33.36718, Longitude: -86.82133, Score: 100.0, Distance: 0.0008033105871356945
# -----
# Booking Hotel: hyatt place birmingham hoover
#   Matched Traffic Hotel: hyatt place birmingham/hoover, Latitude: 33.37108, Longitude: -86.81492, Score: 100.0, Distance: 0.0004408650798215209
# -----
# Booking Hotel: la quinta wyndham birmingham hoover
#   Matched Traffic Hotel: la quinta birmingham hoover, Latitude: 33.35284, Longitude: -86.78491, Score: 100.0, Distance: 0.00034034598292827846
# -----
# Booking Hotel: microtel wyndham hoover birmingham
#   Matched Traffic Hotel: microtel wyndham hoover/birmingham, Latitude: 33.3683, Longitude: -86.81797, Score: 100.0, Distance: 0.00025352491159859417
# -----
# Booking Hotel: residence birmingham hoover
#   Matched Traffic Hotel: residence marriott birmingham/hoover, Latitude: 33.36312, Longitude: -86.82854, Score: 100.0, Distance: 0.00012041680323091886
# -----
# Booking Hotel: fairfield marriott montgomery airport hope hul
#   Matched Traffic Hotel: fairfield marriott montgomery airport, Latitude: 32.27126, Longitude: -86.35695, Score: 100.0, Distance: 0.001479859042236297
# -----
# Booking Hotel: holiday montgomery airport hope hul
#   Matched Traffic Hotel: holiday montgomery airport, Latitude: 32.26851, Longitude: -86.35755, Score: 100.0, Distance: 0.00033240914743850274
# -----
# Booking Hotel: 6 montgomery al airport hope hull
#   Matched Traffic Hotel: 6 montgomery airport hope hull al, Latitude: 32.26751, Longitude: -86.3568, Score: 100.0, Distance: 0.0005426091134433543
# -----
# Booking Hotel: candlewood mobile downtown
#   Matched Traffic Hotel: candlewood downtown, Latitude: 30.69444, Longitude: -88.0418, Score: 100.0, Distance: 0.000386528100539916
# -----
# Booking Hotel: comfort mobile tillmans corner
#   Matched Traffic Hotel: comfort mobile, Latitude: 30.58569, Longitude: -88.1721, Score: 100.0, Distance: 0.0005609688890595003
# -----
# Booking Hotel: courtyard mobile
#   Matched Traffic Hotel: courtyard marriott mobile, Latitude: 30.67025, Longitude: -88.12758, Score: 100.0, Distance: 0.0004180272102460463
# -----
# Booking Hotel: drury mobile
#   Matched Traffic Hotel: drury mobile al, Latitude: 30.6758626651658, Longitude: -88.1320500280688, Score: 100.0, Distance: 0.0027778839860927653
# -----
# Booking Hotel: extended stay america mobile spring hill
#   Matched Traffic Hotel: extended stay america mobile spring hill, Latitude: 30.70503, Longitude: -88.12435, Score: 100.0, Distance: 0.0003636769591343847
# -----
# Booking Hotel: fairfield mobile
#   Matched Traffic Hotel: fairfield marriott mobile, Latitude: 30.67114, Longitude: -88.12761, Score: 100.0, Distance: 0.0005341450343300682
# -----
# Booking Hotel: family inns of america mobile
#   Matched Traffic Hotel: family inns of america mobile, Latitude: 30.67251, Longitude: -88.12762, Score: 100.0, Distance: 0.0002200180561059622
# -----
# Booking Hotel: hampton mobile downtown historic district
#   Matched Traffic Hotel: hampton mobile downtown historic district, Latitude: 30.69105, Longitude: -88.04049, Score: 100.0, Distance: 0.0005026102539707713
# -----
# Booking Hotel: hilton garden mobile downtown
#   Matched Traffic Hotel: hilton garden mobile downtown, Latitude: 30.69222, Longitude: -88.04319, Score: 100.0, Distance: 0.0003591389485753225
# -----
# Booking Hotel: holiday express mobile university
#   Matched Traffic Hotel: holiday express mobile university, Latitude: 30.68879, Longitude: -88.17585, Score: 100.0, Distance: 0.0016063608125214842
# -----
# Booking Hotel: holiday mobile airport
#   Matched Traffic Hotel: holiday mobile airport, Latitude: 30.68041, Longitude: -88.12951, Score: 100.0, Distance: 0.00046470423049834846
# -----
# Booking Hotel: homewood hilton mobile
#   Matched Traffic Hotel: homewood hilton mobile, Latitude: 30.68295, Longitude: -88.20353, Score: 100.0, Distance: 0.00046792910583620375
# -----
# Booking Hotel: homewood mobile
#   Matched Traffic Hotel: homewood hilton mobile i65/airport blvd al, Latitude: 30.66974, Longitude: -88.12759, Score: 100.0, Distance: 0.0008725496578557878
# -----
# Booking Hotel: la quinta wyndham mobile
#   Matched Traffic Hotel: la quinta mobile, Latitude: 30.67537, Longitude: -88.12954, Score: 100.0, Distance: 0.0021047755224719053
# -----
# Booking Hotel: malaga mobile
#   Matched Traffic Hotel: malaga mobile al, Latitude: 30.6875808, Longitude: -88.0444744, Score: 100.0, Distance: 0.0002985190127926199
# -----
# Booking Hotel: mobile marriott
#   Matched Traffic Hotel: marriott mobile, Latitude: 30.67502, Longitude: -88.11674, Score: 100.0, Distance: 0.00028817406285029575
# -----
# Booking Hotel: 6 mobile al airport blvd
#   Matched Traffic Hotel: 6 mobile, Latitude: 30.67878, Longitude: -88.12766, Score: 100.0, Distance: 0.0021386117454071517
# -----
# Booking Hotel: quality airport blvd i 65 mobile
#   Matched Traffic Hotel: quality, Latitude: 30.68141, Longitude: -88.1277, Score: 100.0, Distance: 0.00045269180736005134
# -----
# Booking Hotel: quality downtown historic district mobile
#   Matched Traffic Hotel: quality downtown historic district, Latitude: 30.68817, Longitude: -88.04318, Score: 100.0, Distance: 0.0002366162251352879
# -----
# Booking Hotel: renaissance mobile riverview plaza
#   Matched Traffic Hotel: renaissance mobile riverview plaza, Latitude: 30.69074, Longitude: -88.03908, Score: 100.0, Distance: 0.000857730663486164
# -----
# Booking Hotel: residence mobile
#   Matched Traffic Hotel: residence marriott mobile, Latitude: 30.67113, Longitude: -88.1276, Score: 100.0, Distance: 0.0005315971085696268
# -----
# Booking Hotel: springhill marriott mobile
#   Matched Traffic Hotel: springhill mobile, Latitude: 30.68041, Longitude: -88.12973, Score: 100.0, Distance: 0.001196861311936567
#   Matched Traffic Hotel: springhill marriott, Latitude: 30.681378727673696, Longitude: -88.1294784517099, Score: 100.0, Distance: 0.000737150731041996
# -----
# Booking Hotel: super 8 wyndham mobile
#   Matched Traffic Hotel: super 8 mobile, Latitude: 30.71032, Longitude: -88.12745, Score: 100.0, Distance: 0.00037335534615445104
# -----
# Booking Hotel: the admiral downtown historic district mobile
#   Matched Traffic Hotel: the admiral, Latitude: 30.6902448405326, Longitude: -88.043178601509, Score: 100.0, Distance: 0.0012102074412362889
# -----
# Booking Hotel: the battle house renaissance mobile spa
#   Matched Traffic Hotel: the battle house renaissance mobile spa, Latitude: 30.69296, Longitude: -88.04115, Score: 100.0, Distance: 0.00013881276113375353
# -----
# Booking Hotel: tru hilton mobile
#   Matched Traffic Hotel: tru hilton mobile, Latitude: 30.6472, Longitude: -88.11552, Score: 100.0, Distance: 8.073326513842497e-05
# -----
# Booking Hotel: baymont wyndham montgomery al
#   Matched Traffic Hotel: baymont montgomery, Latitude: 32.36543, Longitude: -86.21018, Score: 100.0, Distance: 0.0022741426956067083
# -----
# Booking Hotel: comfort airport montgomery
#   Matched Traffic Hotel: comfort airport, Latitude: 32.26816, Longitude: -86.35857, Score: 100.0, Distance: 0.0004575148497023796
# -----
# Booking Hotel: drury montgomery
#   Matched Traffic Hotel: drury s montgomery alabama, Latitude: 32.3648282, Longitude: -86.2136659, Score: 100.0, Distance: 0.0002682119475246778
#   Matched Traffic Hotel: drury montgomery al, Latitude: 32.3646569812656, Longitude: -86.2128511883392, Score: 100.0, Distance: 0.0005682714295665097
# -----
# Booking Hotel: renaissance montgomery spa convention center
#   Matched Traffic Hotel: renaissance montgomery spa convention center, Latitude: 32.37987, Longitude: -86.31238, Score: 100.0, Distance: 0.0003569725341046547
# -----
# Booking Hotel: sleep montgomery i 85
#   Matched Traffic Hotel: sleep, Latitude: 32.35978, Longitude: -86.22096, Score: 100.0, Distance: 0.00039583151023606165
#   Matched Traffic Hotel: montgomery, Latitude: 32.36178, Longitude: -86.21955, Score: 100.0, Distance: 0.0022303107820486087
# -----
# Booking Hotel: springhill marriott montgomery downtown
#   Matched Traffic Hotel: springhill marriott montgomery downtown, Latitude: 32.3803, Longitude: -86.3102, Score: 100.0, Distance: 9.481033699718584e-05
# -----
# Booking Hotel: stayapt montgomery
#   Matched Traffic Hotel: montgomery, Latitude: 32.36178, Longitude: -86.21955, Score: 100.0, Distance: 0.003933641696952612
# -----
# Booking Hotel: staybridge montgomery downtown
#   Matched Traffic Hotel: staybridge montgomery downtown, Latitude: 32.37781, Longitude: -86.31142, Score: 100.0, Distance: 7.325742283479664e-05
# -----
# Booking Hotel: comfort pelham hoover i 65
#   Matched Traffic Hotel: comfort, Latitude: 33.33517, Longitude: -86.79068, Score: 100.0, Distance: 0.000448655351572159
# -----
# Booking Hotel: fairfield marriott birmingham pelham i 65
#   Matched Traffic Hotel: fairfield marriott pelham, Latitude: 33.33133, Longitude: -86.79072, Score: 100.0, Distance: 0.0012958688254556259
# -----
# Booking Hotel: holiday express birmingham pelham
#   Matched Traffic Hotel: holiday express birmingham pelham, Latitude: 33.33299, Longitude: -86.78764, Score: 100.0, Distance: 0.0001446095933883399
# -----
# Booking Hotel: quality pelham i 65 exit 246 inn
#   Matched Traffic Hotel: quality inn, Latitude: 33.336, Longitude: -86.78388, Score: 100.0, Distance: 0.00027493241805780504
# -----
# Booking Hotel: ramada wyndham pelham
#   Matched Traffic Hotel: ramada pelham, Latitude: 33.33785, Longitude: -86.78109, Score: 100.0, Distance: 0.00021119014773072337
# -----
# Booking Hotel: sleep pelham oak mountain
#   Matched Traffic Hotel: sleep pelham, Latitude: 33.33493, Longitude: -86.78626, Score: 100.0, Distance: 0.00013327040181243207
# -----
# Booking Hotel: best western apache junction
#   Matched Traffic Hotel: best western apache junction inn, Latitude: 33.41506, Longitude: -111.55799, Score: 100.0, Distance: 0.000396295344407535
# -----
# Booking Hotel: hilton vacation club rancho manana resort cave creek
#   Matched Traffic Hotel: rancho manana resort, Latitude: 33.83226, Longitude: -111.95546, Score: 100.0, Distance: 0.0014809675375611357
# -----
# Booking Hotel: best western gold canyon
#   Matched Traffic Hotel: best western gold canyon, Latitude: 33.35231, Longitude: -111.45603, Score: 100.0, Distance: 0.00015134244414626957
# -----
# Booking Hotel: gold canyon golf resort resort
#   Matched Traffic Hotel: gold canyon golf resort spa, Latitude: 33.36244, Longitude: -111.44569, Score: 100.0, Distance: 0.00033314410695072855
# -----
# Booking Hotel: hampton tucson marana
#   Matched Traffic Hotel: hampton tucson marana, Latitude: 32.38089, Longitude: -111.099, Score: 100.0, Distance: 0.003186834871722754
#   Matched Traffic Hotel: hampton tucson marana, Latitude: 32.37797603392036, Longitude: -111.10006748110094, Score: 100.0, Distance: 0.0004286907037045306
# -----
# Booking Hotel: best western sonora nogales
#   Matched Traffic Hotel: best western sonora, Latitude: 31.36534, Longitude: -110.94765, Score: 100.0, Distance: 0.00032156987420701
# -----
# Booking Hotel: holiday express nogales
#   Matched Traffic Hotel: holiday express nogales, Latitude: 31.36487, Longitude: -110.94873, Score: 100.0, Distance: 0.0003726571748951604
# -----
# Booking Hotel: 6 nogales az mariposa road
#   Matched Traffic Hotel: 6 nogales, Latitude: 31.36718, Longitude: -110.93235, Score: 100.0, Distance: 0.0009062115647021426
# -----
# Booking Hotel: holiday express o valley tucson
#   Matched Traffic Hotel: holiday express o valley tucson, Latitude: 32.40824, Longitude: -110.94381, Score: 100.0, Distance: 0.003833799987722085
# -----
# Booking Hotel: worldmark rancho vistoso o valley
#   Matched Traffic Hotel: worldmark rancho vistoso, Latitude: 32.44883, Longitude: -110.97738, Score: 100.0, Distance: 0.0009404525496338538
# -----
# Booking Hotel: boulders resort spa scottsdale curio collection hilton resort
#   Matched Traffic Hotel: boulders resort spa curio collection hilton, Latitude: 33.80379, Longitude: -111.92762, Score: 100.0, Distance: 0.0013154161313460332
# -----
# Booking Hotel: days wyndham willcox
#   Matched Traffic Hotel: days willcox, Latitude: 32.26137, Longitude: -109.84137, Score: 100.0, Distance: 0.003341262592432179
# -----
# Booking Hotel: studio 6 willcox az
#   Matched Traffic Hotel: 6 willcox, Latitude: 32.26537, Longitude: -109.84138, Score: 100.0, Distance: 0.001770697037885471
# -----
# Booking Hotel: comfort bryant benton
#   Matched Traffic Hotel: comfort bryant, Latitude: 34.62085, Longitude: -92.4991, Score: 100.0, Distance: 0.0008322706879355108
#   Matched Traffic Hotel: comfort, Latitude: 34.6197412398291, Longitude: -92.4993262010194, Score: 100.0, Distance: 0.00053162790020902
# -----
# Booking Hotel: country radisson bryant little rock ar
#   Matched Traffic Hotel: country, Latitude: 34.6213738, Longitude: -92.4963639, Score: 100.0, Distance: 0.00024082386136101217
# -----
# Booking Hotel: la quinta wyndham little rock bryant
#   Matched Traffic Hotel: la quinta bryant, Latitude: 34.62092, Longitude: -92.50058, Score: 100.0, Distance: 0.000461670350465802
# -----
# Booking Hotel: days wyndham cabot
#   Matched Traffic Hotel: days cabot, Latitude: 34.98052, Longitude: -92.0295, Score: 100.0, Distance: 0.0003656817207625537
# -----
# Booking Hotel: super 8 wyndham cabot
#   Matched Traffic Hotel: super 8 cabot, Latitude: 34.97926, Longitude: -92.02942, Score: 100.0, Distance: 0.0004887289637355829
# -----
# Booking Hotel: 1886 crescent spa eureka springs
#   Matched Traffic Hotel: 1886 crescent spa, Latitude: 36.40755, Longitude: -93.73902, Score: 100.0, Distance: 0.0017695296342504104
# -----
# Booking Hotel: 1905 basin park eureka springs
#   Matched Traffic Hotel: basin park, Latitude: 36.4022, Longitude: -93.73719, Score: 100.0, Distance: 0.0002007286051679119
# -----
# Booking Hotel: best western of ozarks eureka springs
#   Matched Traffic Hotel: best western of ozarks, Latitude: 36.39905, Longitude: -93.74734, Score: 100.0, Distance: 9.823441352563754e-05
# -----
# Booking Hotel: osage creek lodge eureka springs
#   Matched Traffic Hotel: osage creek lodge, Latitude: 36.3940142, Longitude: -93.7416031, Score: 100.0, Distance: 0.0003941774841777941
# -----
# Booking Hotel: quality eureka springs
#   Matched Traffic Hotel: quality eureka springs, Latitude: 36.3879, Longitude: -93.7361, Score: 100.0, Distance: 9.99999999891088e-05
# -----
# Booking Hotel: super 8 wyndham eureka springs
#   Matched Traffic Hotel: eureka, Latitude: 36.39226, Longitude: -93.73052, Score: 100.0, Distance: 0.0026393301395822447
# -----
# Booking Hotel: best western windsor fayetteville
#   Matched Traffic Hotel: best western windsor, Latitude: 36.0516, Longitude: -94.19255, Score: 100.0, Distance: 0.0027406772885561433
# -----
# Booking Hotel: candlewood fayetteville
#   Matched Traffic Hotel: candlewood fayetteville â€“ university of arkansas, Latitude: 36.05454, Longitude: -94.19176, Score: 100.0, Distance: 0.001607649618849853
#   Matched Traffic Hotel: candlewood fayetteville ar, Latitude: 36.0559025, Longitude: -94.1910402, Score: 100.0, Distance: 0.00012106701036930914
# -----
# Booking Hotel: comfort fayetteville university
#   Matched Traffic Hotel: comfort fayetteville, Latitude: 36.07943, Longitude: -94.20384, Score: 100.0, Distance: 0.0006703613258522236
# -----
# Booking Hotel: courtyard marriott fayetteville
#   Matched Traffic Hotel: courtyard marriott fayetteville, Latitude: 36.11773, Longitude: -94.15013, Score: 100.0, Distance: 0.0009431234786667858
#   Matched Traffic Hotel: fayetteville, Latitude: 36.11474, Longitude: -94.14746, Score: 100.0, Distance: 0.0035818037210333135
# -----
# Booking Hotel: days wyndham fayetteville
#   Matched Traffic Hotel: days fayetteville, Latitude: 36.05814, Longitude: -94.1973, Score: 100.0, Distance: 0.0006045979825505744
# -----
# Booking Hotel: fairfield marriott fayetteville
#   Matched Traffic Hotel: fayetteville, Latitude: 36.11474, Longitude: -94.14746, Score: 100.0, Distance: 0.004275526283395982
#   Matched Traffic Hotel: fairfield marriott fayetteville, Latitude: 36.11885, Longitude: -94.1469, Score: 100.0, Distance: 0.00017602556632667762
# -----
# Booking Hotel: hampton fayetteville
#   Matched Traffic Hotel: hampton fayetteville ga, Latitude: 33.4493039, Longitude: -84.4621198, Score: 100.0, Distance: 0.000325808215059632
# -----
# Booking Hotel: hilton garden fayetteville convention center
#   Matched Traffic Hotel: hilton garden fayetteville, Latitude: 36.0805, Longitude: -94.20022, Score: 100.0, Distance: 0.002297094869344865
# -----
# Booking Hotel: homewood hilton fayetteville
#   Matched Traffic Hotel: homewood hilton fayetteville, Latitude: 36.07969, Longitude: -94.20377, Score: 100.0, Distance: 0.0015108616188545853
# -----
# Booking Hotel: at carnall hall fayetteville
#   Matched Traffic Hotel: at carnall hall, Latitude: 36.06977, Longitude: -94.16893, Score: 100.0, Distance: 0.0003346711460499149
# -----
# Booking Hotel: la quinta wyndham fayetteville
#   Matched Traffic Hotel: fayetteville, Latitude: 36.11474, Longitude: -94.14746, Score: 100.0, Distance: 0.0005064606182108158
# -----
# Booking Hotel: 6 fayetteville ar
#   Matched Traffic Hotel: 6 fayetteville ar, Latitude: 36.10592, Longitude: -94.14656, Score: 100.0, Distance: 0.0003286265547654642
# -----
# 2238

# %%
print(matched_hotels)
# Out:
# []

# %%
import hashlib
hash = hashlib.md5(b'booking.com/url').hexdigest()
print(hash)
# Out:
# 9cbd4f9d6788301e6299a794ceba1c95

# %%
hashed_booking_hotels = []

hotel_hashes = {hotel : hashlib.md5(hotel.encode('utf-8')).hexdigest() for hotel in matched_booking_hotels}

for hotel, hash_value in hotel_hashes.items():
    print(f"Hotel: {hotel} => Hash: {hash_value}")
# Out:
# Hotel: candlewood alabaster => Hash: aab9e2ec7ce4e73c3627d3162eb29ed0
# Hotel: microtel wyndham albertville => Hash: b94c14e52ce35bcb8980c558307784e1
# Hotel: econo lodge boaz => Hash: dcafc4ceac28fa01b3ae6c2d047032fd
# Hotel: key boaz => Hash: 1a42759e76e64cf4bc98e4ea4140d615
# Hotel: hampton calera => Hash: 32323cbe74f8086ca75d7ce9667db767
# Hotel: comfort cullman i 65 exit 310 => Hash: 152ffd641d8193ffb1cb7049d8073030
# Hotel: hampton cullman => Hash: 4257128f4b6f35aee9d83568cc69ccef
# Hotel: la quinta wyndham cullman => Hash: afa9210454540e53f88d4b11ea410d20
# Hotel: quality cullman i 65 exit 310 inn => Hash: 27863fa9b0a48c1ce768f87392df1e2a
# Hotel: sleep cullman i 65 exit 310 => Hash: 71b50daf64f9d27e711fe6201403073f
# Hotel: econo lodge fort payne => Hash: 4967069777848225242fc971a770fb79
# Hotel: hampton guntersville => Hash: 0fe914d54be7917558e6d63fd2094aa4
# Hotel: wyndham garden lake guntersville => Hash: 0a06a8cb81f22b80004654ba8c8ce44d
# Hotel: courtyard birmingham hoover => Hash: 2022af76373461e4a9017f9ec949b74d
# Hotel: embassy hilton birmingham hoover => Hash: e04b4d32cea12768698d374b5afda3f7
# Hotel: hampton birmingham hoover galleria => Hash: 7098b100dbf2809205825d27f472b337
# Hotel: holiday birmingham hoover => Hash: 20d72562612cca68bdd188703b4ad194
# Hotel: hyatt place birmingham hoover => Hash: c71dae22216aed883defbe14b12e4c69
# Hotel: la quinta wyndham birmingham hoover => Hash: 9b8adaf1dcaf8459d5452b3b666c69fd
# Hotel: microtel wyndham hoover birmingham => Hash: 0df0ccecffc9a6b197984a963f4ae33a
# Hotel: residence birmingham hoover => Hash: 6191d99e83c38881c4e5804f96f6ca9e
# Hotel: fairfield marriott montgomery airport hope hul => Hash: 4a60b6601129f8258cba9a848b70a802
# Hotel: holiday montgomery airport hope hul => Hash: 63c956995a8dc1ec63ee7e26684b4114
# Hotel: 6 montgomery al airport hope hull => Hash: a712d2f99ec6cf810dbe0aa6e7adb0dd
# Hotel: candlewood mobile downtown => Hash: c8e4f1aab817f3732ab86f41c6e6d40e
# Hotel: comfort mobile tillmans corner => Hash: 25dd2ec6aa6ca2e8f5901019f8cc2d12
# Hotel: courtyard mobile => Hash: 4e494ed94bf01d026c726771626e5161
# Hotel: drury mobile => Hash: f106e2f2529a155b90da9141ce060b2a
# Hotel: extended stay america mobile spring hill => Hash: 82430645b4923a817ac387428f69a497
# Hotel: fairfield mobile => Hash: edb34dfc762b186adb0e8d208559ed40
# Hotel: family inns of america mobile => Hash: 0b4328c506d94e9bcd53eb5bae96e7e1
# Hotel: hampton mobile downtown historic district => Hash: aa79117b1d1620755a7814fcb818deb8
# Hotel: hilton garden mobile downtown => Hash: cccf3d5824d5618f1f1154f87cf8b7bb
# Hotel: holiday express mobile university => Hash: 2cf5fd827763c13f74ee1d5001d06433
# Hotel: holiday mobile airport => Hash: 00818c555f14dfcd033fb90d6b1ba402
# Hotel: homewood hilton mobile => Hash: d9aef161e4b56e8d6c3c286bb1f6e9c0
# Hotel: homewood mobile => Hash: 8b8fdde65b1cd23ab2e8836cca13e19a
# Hotel: la quinta wyndham mobile => Hash: be6021556c54def7b2404db5a357ce7c
# Hotel: malaga mobile => Hash: 2e1c239714938eb9ef4ee961bb1b7041
# Hotel: mobile marriott => Hash: 1e31e88830e65ff9ae90603ca3220653
# Hotel: 6 mobile al airport blvd => Hash: 7989d21f79f467bd8bc68563b1346e8d
# Hotel: quality airport blvd i 65 mobile => Hash: d62b03242110d1b891a62b7031457525
# Hotel: quality downtown historic district mobile => Hash: 1a29b7b0ce027c010d11a41eb14c9944
# Hotel: renaissance mobile riverview plaza => Hash: ef5a4296208fa39bacba53c86a4c05c9
# Hotel: residence mobile => Hash: 65fe48bd2b84f90d11706876cf9f20c4
# Hotel: springhill marriott mobile => Hash: b80cf19e47721023ce49f72d6adff4e4
# Hotel: super 8 wyndham mobile => Hash: 38b86a7ba1288d312bd7a950a30102a0
# Hotel: the admiral downtown historic district mobile => Hash: 2ca4802f7724935f1ac49bea62881cc2
# Hotel: the battle house renaissance mobile spa => Hash: afcb895ddd84e1cf0eb962ede3ada0c3
# Hotel: tru hilton mobile => Hash: 4f131e1f91803f1245ce76146e403e8c
# Hotel: baymont wyndham montgomery al => Hash: a74e5ad72866b6be2417c7458d676e5c
# Hotel: comfort airport montgomery => Hash: ba6c49e06945e50be5b85606e955c9ce
# Hotel: drury montgomery => Hash: 0025d51ee3c3b15b7d0a29a808f371a1
# Hotel: renaissance montgomery spa convention center => Hash: 4955377d1a11405b076d3b22d378a666
# Hotel: sleep montgomery i 85 => Hash: 81394a5493cd1344c7425713e3fe5e7d
# Hotel: springhill marriott montgomery downtown => Hash: 37ff39b87cb7b09a853830c148cabea1
# Hotel: stayapt montgomery => Hash: a685c18e84ad5edbda869aa72edb6696
# Hotel: staybridge montgomery downtown => Hash: 719aaad7a3553ba5df8bcf7b7192a8f6
# Hotel: comfort pelham hoover i 65 => Hash: 8c097626ecee06a4e02962eee6807432
# Hotel: fairfield marriott birmingham pelham i 65 => Hash: a8abd03a6aa4155b46b24aaea855bb32
# Hotel: holiday express birmingham pelham => Hash: e777a0191f1082a157c56cb5cf5c6f6b
# Hotel: quality pelham i 65 exit 246 inn => Hash: 30a3120de009bb4f465aa3e37499adf4
# Hotel: ramada wyndham pelham => Hash: 655dfb8d05a4aa0478e70436f74e7182
# Hotel: sleep pelham oak mountain => Hash: 34191e56d64bdb6aab8eef3ec73a1495
# Hotel: best western apache junction => Hash: fcd68f94f2e11906667d589aed6cea95
# Hotel: hilton vacation club rancho manana resort cave creek => Hash: 9cd5b61ac6242e762fc380f23764f752
# Hotel: best western gold canyon => Hash: 2fff3cb94f525cd083c83f021eab2f26
# Hotel: gold canyon golf resort resort => Hash: e1f02e5f0e1e622e2f6e4d9597b878c6
# Hotel: hampton tucson marana => Hash: 14d30f924e008b9c9ded2df9e2968d22
# Hotel: best western sonora nogales => Hash: 56d584040d025481cee9dacfe3240cca
# Hotel: holiday express nogales => Hash: efda435e6bf54ee012ae2d917f713a55
# Hotel: 6 nogales az mariposa road => Hash: 0f00d2d70ebd27238af042e0188a50cf
# Hotel: holiday express o valley tucson => Hash: 2d7bd0f193034054a4c39b76a27338af
# Hotel: worldmark rancho vistoso o valley => Hash: 79b61f57d65ec5df7be82861fd226746
# Hotel: boulders resort spa scottsdale curio collection hilton resort => Hash: a277a80b418eb4e935a66f887d7b0ce0
# Hotel: days wyndham willcox => Hash: 4ed293cb5d65b50b9b2f430e569e396d
# Hotel: studio 6 willcox az => Hash: b9c5a13f2f0fde2c1a3195728ff8b1a8
# Hotel: comfort bryant benton => Hash: e79de17282a50ab4d5e6c11feb3ef497
# Hotel: country radisson bryant little rock ar => Hash: c5e0d03895703f749b2d95c0b9c5c665
# Hotel: la quinta wyndham little rock bryant => Hash: eefa1b7b0fbdff0e55d862270d1a3a3b
# Hotel: days wyndham cabot => Hash: 079ad00f9d0b7a3ee772f153c90f6916
# Hotel: super 8 wyndham cabot => Hash: bb283379dd62bd50a24a1a0b9469f0c2
# Hotel: 1886 crescent spa eureka springs => Hash: f9409ac5fcd49b928b79b2d8a39f3cd1
# Hotel: 1905 basin park eureka springs => Hash: a3ca377c4d3afcb58cdbcddfa0c9bd11
# Hotel: best western of ozarks eureka springs => Hash: 940360826a84a64d0b1cef213bf71a3f
# Hotel: osage creek lodge eureka springs => Hash: 75389c898f2636d77fc5047d0916f078
# Hotel: quality eureka springs => Hash: 95280936705d68002529112923791985
# Hotel: super 8 wyndham eureka springs => Hash: 4a3c3af6c108153ec28f194e825ee4ae
# Hotel: best western windsor fayetteville => Hash: 1c099aae71941b156a0c39de11dec155
# Hotel: candlewood fayetteville => Hash: 9ef59c3792216cf6b68924b9bac2a522
# Hotel: comfort fayetteville university => Hash: 9c11be7c98fe2be335d80cdbafd9fa12
# Hotel: courtyard marriott fayetteville => Hash: 82dac0cedc98d3934dbce8ccfe9acf29
# Hotel: days wyndham fayetteville => Hash: ea427f596ef527fcc8707369d011f305
# Hotel: fairfield marriott fayetteville => Hash: 01187e9c2a9616838f6383217ad19286
# Hotel: hampton fayetteville => Hash: 7ed6a362647443da46666e79e166ca98
# Hotel: hilton garden fayetteville convention center => Hash: 2d88399bffc9027906e1c185c178bcad
# Hotel: homewood hilton fayetteville => Hash: bff8524a024aa783ce553fa484b45eb5
# Hotel: at carnall hall fayetteville => Hash: ad0be4581ddf3e9c28e271986d23e46e
# Hotel: la quinta wyndham fayetteville => Hash: 3192bca9312786226cd6bc710c858275
# Hotel: 6 fayetteville ar => Hash: 42d802e536c359c6befec6fd236c8bb8
