# %%
# Load hotels

# %%
# For loop goign through each hotel, checking if it has a match in traffic dataset,
# then creates a hash of the url, then checks if hash and hotel id are already in downloaded
# file, then calls download image function, then saves images the to downloaded file

# %%
# NEED FUNCTIONS FOR: 
# 1. checking if it has a match in traffic dataset
# 2. creating a hash of the url
# 3. checking if the hash and hotel id are already downloaded in file
# 4. downloading the images
# 5. saves the image to the download file

# %%
import numpy as np
import pandas as pd
import os
import hashlib
from scipy.spatial.distance import cdist
from rapidfuzz import fuzz, utils
import json
import requests
from urllib.parse import urlparse
import random

# %%
# Splits the gps column in the booking.com data
def split_gps_column(sharded_data):
    if 'gps' in sharded_data.columns:
        # Split the 'gps' column on the delimiter (assuming comma, adjust if necessary)
        sharded_data[['latitude', 'longitude']] = sharded_data['gps'].str.split(',', expand=True)
        
        # Convert latitude and longitude to numeric types
        sharded_data['latitude'] = pd.to_numeric(sharded_data['latitude'], errors='coerce')
        sharded_data['longitude'] = pd.to_numeric(sharded_data['longitude'], errors='coerce')

        # Drop the 'gps' column after splitting
        sharded_data.drop('gps', axis=1, inplace=True)
    
    return sharded_data

# %%
def remove_after_near(s):
    index = s.lower().find("near")
    return s[:index].strip() if index != -1 else s

# %%
# Load the TraffickCam data
def loadTraffickCam(path):
    with open(path, 'r', encoding='utf-8') as file:  # Specify utf-8 encoding
        txt_data = file.readlines()
    
    txt_data = [line.strip().split('\t') for line in txt_data]

    columns = ['number', 'hotel_name', 'latitude', 'longitude', 'places_id']
    txt_data_df = pd.DataFrame(txt_data, columns=columns)

    txt_data_df['longitude'] = pd.to_numeric(txt_data_df['longitude'], errors='coerce')
    txt_data_df['latitude'] = pd.to_numeric(txt_data_df['latitude'], errors='coerce')
    txt_data_df.dropna(subset=['longitude', 'latitude'], inplace=True)

    return txt_data_df

# %%
# Load the sharded booking.com data
def load_sharded_dataset(root_dir):
    all_data = []
    print("after making list")
    try:
        print("after try")
        for root, dirs, files in os.walk(root_dir):
            #print("in for loop")
            #print(f"Scanning directory: {root}")  # Log current directory being scanned
            
            if not files:
                print(f"No files found in directory: {root}")
                continue  # Skip directories with no files
            
            for file in files:
                file_path = os.path.join(root, file)
                #print(f"Attempting to load file: {file_path}")  # Log which file is being loaded
                
                # Check file extension and load accordingly
                if file.endswith('.csv'):
                    try:
                        data = pd.read_csv(file_path)
                        all_data.append(data)
                        #print(f"Successfully loaded {file_path} with {len(data)} records.")
                    except Exception as e:
                        print(f"Error loading {file_path}: {e}")
                elif file.endswith('.json'):
                    try:
                        data = pd.read_json(file_path)
                        all_data.append(data)
                        #print(f"Successfully loaded {file_path} with {len(data)} records.")
                    except Exception as e:
                        print(f"Error loading {file_path}: {e}")
                else:
                    print(f"Skipping unsupported file format: {file_path}")
    
    except Exception as e:
        print(f"Exception occurred during directory traversal: {e}")
    
    # Ensure we're returning a single combined DataFrame
    if all_data:
        combined_data = pd.concat(all_data, ignore_index=True)

        if 'images' not in combined_data.columns:
            combined_data['images'] = [[] for _ in range(len(combined_data))]

        combined_data = combined_data.groupby(
            ["hotel_name", "address", "gps", "rating", "url"], dropna=False
        )["images"].agg(lambda x: sum(x, []) if isinstance(x.iloc[0], list) else list(x)).reset_index()

        combined_data["hotel_name"] = combined_data["hotel_name"].str.replace('-', ' ')

        print(f"Loaded {len(all_data)} files, combined into one DataFrame.")

        split_gps_column(combined_data)
        return combined_data
    else:
        print("No data loaded.")
        return None

# %%
import hashlib

# Creates the has of the booking.com url
def hash_url(url):
    b_url = str.encode(str(url)) # turns the url into bytes in order to be hashed
    hash = hashlib.md5(b_url).hexdigest() # Hashes the byte-form url using md5 algorithm
    
    return hash

# %%
# Clean hotel names
def clean_hotel_names(booking_df, traffic_df):
    bookinglatlng = np.vstack([booking_df["latitude"].to_numpy(), booking_df["longitude"].to_numpy()]).T
    bookingHotelNames = booking_df["hotel_name"].fillna("").to_numpy().astype(str)
    bookingHotelURL = booking_df["url"].fillna("").to_numpy().astype(str)
    bookingImages = booking_df["images"].to_numpy()
    
    trafficlatlng = np.vstack([traffic_df["latitude"].to_numpy(), traffic_df["longitude"].to_numpy()]).T
    trafficHotelNames = traffic_df["hotel_name"].fillna("").to_numpy().astype(str)
    trafficHotelID = traffic_df["places_id"].fillna("").to_numpy().astype(str)

    # List of phrases to omit
    phrases_to_omit = ["hotel", "motel", "bed and breakfast", "inn ", "&", "suites", " and", " by", " or", 
                    " the", " an", "ihg", " at", " area", " north", " south", " east", "west "]

    # Convert to lowercase
    cleanedBookingHotelNames = np.char.lower(bookingHotelNames)
    cleanedTrafficHotelNames = np.char.lower(trafficHotelNames)

    # Remove punctuation
    unwanted_chars = "()-.,!?"
    translation_table = str.maketrans('', '', unwanted_chars)
    cleanedBookingHotelNames = np.char.translate(cleanedBookingHotelNames, translation_table)
    cleanedTrafficHotelNames = np.char.translate(cleanedTrafficHotelNames, translation_table)

    # Remove phrases
    for phrase in phrases_to_omit:
        cleanedBookingHotelNames = np.char.replace(cleanedBookingHotelNames, phrase, "")
        cleanedTrafficHotelNames = np.char.replace(cleanedTrafficHotelNames, phrase, "")

    # Remove double spaces
    cleanedBookingHotelNames = np.char.replace(cleanedBookingHotelNames, '  ', ' ')
    cleanedTrafficHotelNames = np.char.replace(cleanedTrafficHotelNames, '  ', ' ')

    # Remove words after "near"
    remove_after_near_vec = np.vectorize(remove_after_near)
    cleanedBookingHotelNames = remove_after_near_vec(cleanedBookingHotelNames)
    cleanedTrafficHotelNames = remove_after_near_vec(cleanedTrafficHotelNames)

    # Strip whitespace
    cleanedBookingHotelNames = np.char.strip(cleanedBookingHotelNames)
    cleanedTrafficHotelNames = np.char.strip(cleanedTrafficHotelNames)

    print(type(cleanedBookingHotelNames))

    # Create final DataFrames
    booking_df_final = pd.DataFrame({
        "index": np.arange(len(cleanedBookingHotelNames)),
        "cleanedHotelName": cleanedBookingHotelNames,
        "latitude": bookinglatlng[:, 0],
        "longitude": bookinglatlng[:, 1],
        "url": bookingHotelURL,
        "images": bookingImages
    })

    traffic_df_final = pd.DataFrame({
        "cleanedHotelName": cleanedTrafficHotelNames,
        "latitude": trafficlatlng[:, 0],
        "longitude": trafficlatlng[:, 1],
        "places_id": trafficHotelID
    })

    return booking_df_final, traffic_df_final

# %%
def find_distances(booking_df, traffic_df):
    # Initialize arrays to store the 10 closest indices and distances for each point

    latlon_small = np.vstack([np.array(booking_df["latitude"]), np.array(booking_df["longitude"])]).T # Now (3906, 2)
    latlon_large = np.vstack([np.array(traffic_df["latitude"]), np.array(traffic_df["longitude"])]).T  # Now (625138, 2)
    # Compute the pairwise Euclidean distances

    #hotel_name_small = bookingHotelNames.T
    hotel_name_small = np.vstack([np.array(booking_df["cleanedHotelName"])]).T
    hotel_name_large = np.vstack([np.array(traffic_df["cleanedHotelName"])]).T

    booking_urls = np.vstack([np.array(booking_df["url"])]).T
    traffic_places_id = np.vstack([np.array(traffic_df["places_id"])]).T

    unique_latlon_large = np.unique(latlon_large, axis=0)

    num_small = latlon_small.shape[0]

    closest_indices = []
    closest_distances = []
    similarity_scores = []

    distance_threshold = 0.0045

    # Loop through each point in the smaller array
    for i in range(num_small):
        # Compute distances between the ith point in latlon_small and all points in latlon_large
        distances = cdist(latlon_small[i:i+1], latlon_large).flatten()  # distances shape (625138,)

        # Filter indices where the distance is within 500 meters (threshold)
        within_threshold_idx = np.where(distances <= distance_threshold)[0]
        
        # Store the closest indices and corresponding distances
        closest_indices.append(within_threshold_idx)
        closest_distances.append(distances[within_threshold_idx])

        print(f"Points within 500 meters of point {i}: {within_threshold_idx}, Distances: {distances[within_threshold_idx]}")

        ref_hotel_name = hotel_name_small[i].flatten()

        # Compute similarity scores for points within the threshold
        similarity_scores_for_point = []
        for j in range(len(within_threshold_idx)):
            closest_hotel_name = hotel_name_large[within_threshold_idx[j]].flatten()

            # Compute the similarity score using fuzzy string matching
            similarity_score = fuzz.token_set_ratio(str(ref_hotel_name), str(closest_hotel_name), processor=utils.default_process)
            similarity_scores_for_point.append(similarity_score)

            if similarity_score >= 85.1:
                print(f"Similarity score between '{ref_hotel_name}' and '{closest_hotel_name}': {similarity_score}")
        
        similarity_scores.append(similarity_scores_for_point)

        print("-----------")

        if i > 250:
            break

# %%
def match_hotels(booking_df, traffic_df):

    # Initialize arrays to store the 10 closest indices and distances for each point
    latlon_small = np.vstack([np.array(booking_df["latitude"]), np.array(booking_df["longitude"])]).T # Now (3906, 2)
    latlon_large = np.vstack([np.array(traffic_df["latitude"]), np.array(traffic_df["longitude"])]).T  # Now (625138, 2)
    # Compute the pairwise Euclidean distances

    #hotel_name_small = bookingHotelNames.T
    hotel_name_small = np.vstack([np.array(booking_df["cleanedHotelName"])]).T
    hotel_name_large = np.vstack([np.array(traffic_df["cleanedHotelName"])]).T

    booking_urls = np.vstack([np.array(booking_df["url"])]).T
    traffic_places_id = np.vstack([np.array(traffic_df["places_id"])]).T

    # Extract image lists and ensure correct format
    booking_images = np.array(booking_df["images"], dtype=object)

    num_small = latlon_small.shape[0]

    closest_indices = []
    closest_distances = []
    similarity_scores = []

    distance_threshold = 0.0045

    # Loop through each point in the smaller array
    for i in range(num_small):
        # Compute distances between the ith point in latlon_small and all points in latlon_large
        distances = cdist(latlon_small[i:i+1], latlon_large).flatten()  # distances shape (625138,)

        # Filter indices where the distance is within 500 meters (threshold)
        within_threshold_idx = np.where(distances <= distance_threshold)[0]
        
        # Store the closest indices and corresponding distances
        closest_indices.append(within_threshold_idx)
        closest_distances.append(distances[within_threshold_idx])

        #print(f"Points within 500 meters of point {i}: {within_threshold_idx}, Distances: {distances[within_threshold_idx]}")

        ref_hotel_name = hotel_name_small[i].flatten()

        # Compute similarity scores for points within the threshold
        similarity_scores_for_point = []
        for j in range(len(within_threshold_idx)):
            closest_hotel_name = hotel_name_large[within_threshold_idx[j]].flatten()
            
            # Compute the similarity score using fuzzy string matching
            similarity_score = fuzz.token_set_ratio(str(ref_hotel_name), str(closest_hotel_name), processor=utils.default_process)
            similarity_scores_for_point.append(similarity_score)

            '''if similarity_score >= 85.1:
                print(f"Similarity score between '{ref_hotel_name}' and '{closest_hotel_name}': {similarity_score}")'''
        
        similarity_scores.append(similarity_scores_for_point)

        #print("-----------")

    # Ensure closest_indices and closest_distances have the same length as num_small
    #num_small = 252
    '''if len(closest_indices) != num_small or len(closest_distances) != num_small:
        print("Error: Length mismatch between closest_indices/closest_distances and num_small.")
        print(f"Expected length: {num_small}, closest_indices length: {len(closest_indices)}, closest_distances length: {len(closest_distances)}")
        raise ValueError("Mismatch in lengths between closest_indices/closest_distances and num_small.")
    '''

    # Initialize the dictionary to store matches
    matches = {}

    # Define the similarity score threshold for a match
    similarity_threshold = 100

    # Loop through each point in the smaller dataset (bookingData)
    for i in range(num_small):
        #print("here2")
        # Safety check in case of indexing issues
        if i >= len(closest_indices) or i >= len(closest_distances):
            print(f"Skipping index {i} due to out-of-range access.")
            continue

        booking_hotel_name = str(hotel_name_small[i][0])  # Get the booking hotel name as a string

        # Check if there are matches within the threshold for this booking hotel
        if len(closest_indices[i]) == 0:
            continue

        # List to hold matches for the current booking hotel
        matched_hotels = []

        # Iterate over each matching traffic hotel within the distance threshold
        for j, idx in enumerate(closest_indices[i]):
            #print("here3")
            similarity_score = similarity_scores[i][j]
          
            # Only add matches that meet or exceed the similarity threshold
            if similarity_score >= similarity_threshold:
                # Prepare match details
                traffic_hotel_name = str(hotel_name_large[idx][0])  # Traffic hotel name as string
                lat, lon = latlon_large[idx]  # Traffic hotel coordinates
                dist = closest_distances[i][j]  # Distance to booking hotel
                b_url = booking_urls[i][0]
                b_index = booking_df["index"][i]
                b_images = booking_images[i]

                # Append the match details to the list
                matched_hotels.append({
                    "index": b_index,
                    "traffic_hotel_name": traffic_hotel_name,
                    "url": b_url,
                    "latitude": lat,
                    "longitude": lon,
                    "similarity_score": similarity_score,
                    "distance": dist,
                    "images": b_images
                })

        # Only add the booking hotel to the dictionary if there are matches
        if matched_hotels:
            matches[booking_hotel_name] = matched_hotels
            
    matched_booking_hotels = []
    # Print out the first few matches for inspection
    for booking_hotel, traffic_matches in list(matches.items())[:100]:
        print(f"Booking Hotel: {booking_hotel}")
        for match in traffic_matches:
            print(f"  Matched Traffic Hotel: {match['traffic_hotel_name']}, "
                f"Latitude: {match['latitude']}, Longitude: {match['longitude']}, "
                f"Score: {match['similarity_score']}, Distance: {match['distance']}")
        matched_booking_hotels.append(booking_hotel)
        print("-----")

    return matches

# %%
def hash_url(url):
    hash_value = hashlib.md5(str(url).encode('utf-8')).hexdigest()
    return hash_value

# %%
# Checks to see if the url has has already had its images downloaded from it
def predownload_check(hash_to_check):
    # Ensure the file exists
    file_path = "downloaded_hashes.txt"
    if not os.path.exists(file_path):
        with open(file_path, 'w') as f:
            pass  # Create an empty file
    
    # Read the file and check for the hash
    with open(file_path, 'r') as f:
        lines = f.readlines()
    
    check = hash_to_check in (line.strip() for line in lines)
    print(check)
    return check

# %%
def get_sharded_path(root_directory, index, levels=3):
    """Generate a sharded directory path based on an index."""
    index_str = f"{index:06d}"  # Zero-padded index (e.g., 000123)
    shards = [index_str[i:i+2] for i in range(0, levels * 2, 2)]  # Create 2-char directory levels
    return os.path.join(root_directory, *shards)

# %%
def generate_hashed_directory_name(url):
    """Generate a directory name using a random number and a hashed version of the URL."""
    random_number = random.randint(100000, 999999)  # Generate a random 6-digit number
    url_hash = hashlib.md5(url.encode('utf-8')).hexdigest()  # Hash the URL (first 8 chars for brevity)
    return f"{random_number}_{url_hash}"

# %%
def download_single_image(url, save_directory):
    try:
        # Get the file name from the URL
        parsed_url = urlparse(url)
        file_name = os.path.basename(parsed_url.path)
        save_path = os.path.join(save_directory, file_name)

        # Ensure the save directory exists
        os.makedirs(save_directory, exist_ok=True)

        # Download the image
        response = requests.get(url, stream=True)
        response.raise_for_status()  # Raise an error for HTTP errors

        # Save the image
        with open(save_path, 'wb') as image_file:
            for chunk in response.iter_content(1024):
                image_file.write(chunk)
        print(f"Downloaded: {url} -> {save_path}")
    except Exception as e:
        print(f"Failed to download {url}: {e}")

# %%
def download_all_images(matches_dict, root_directory, log_file = "downloaded_hashes.txt"):

    with open(log_file, "a") as log:
        for hotel_name, matched_hotels in matches_dict.items():
            for match in matched_hotels:
                hotel_index = match["index"]
                image_urls = match["images"]
                match_url = match["url"]

                if not image_urls:
                    print(f"No images found for hotel: {hotel_name}")
                    continue

                parent_directory = get_sharded_path(root_directory, hotel_index)

                lowest_level_directory = generate_hashed_directory_name(match_url)
                save_directory = os.path.join(parent_directory, lowest_level_directory)

                os.makedirs(save_directory, exist_ok=True)
                hashed_url = hash_url(match_url)

                if predownload_check(hashed_url) == False:
                    for image_url in image_urls:
                        download_single_image(image_url, save_directory)
                    
                    print(f"Finished downloading images for hotel: {hotel_name}")
                    log.write(hashed_url + "\n")
                else:
                    continue

# %% [markdown]
# START OF MAIN

# %%
#Load TraffickCam Data
traffickCamData = loadTraffickCam("hotel_info_with_places_id.txt")
traffickCamData.head
# Out:
# <bound method NDFrame.head of         number                                         hotel_name   latitude  \
# 0          390                                  Super 8 Frederick  39.402160
# 1          391  Extended Stay America - Fairbanks - Old Airpor...  64.835380
# 2          392                Hilton Hangzhou Qiandao Lake Resort  29.608190
# 3          393                                      Taj Lands End  19.043910
# 4          394        Helzear Montparnasse Rive Gauche Apartments  48.834660
# ...        ...                                                ...        ...
# 625133  694001   Hyatt Regency Lake Washington at Seattle’s So...  47.503043
# 625134  694002                                 The Beverly Hilton  34.066370
# 625135  694003               Homewood Suites by Hilton Ronkonkoma  40.812062
# 625136  694004                                  Choctaw Durant OK  33.958543
# 625137  694005                                            ???????  24.125850
#
#          longitude                    places_id
# 0       -77.408420  ChIJCWJjR0HayYkRAfWSLQl85IQ
# 1      -147.823300  ChIJqbFJVhdbMlERYHgGtF-Gv8w
# 2       119.072900  ChIJDZWWXAOLSTQR4JoKtpTbZEE
# 3        72.818790  ChIJSRH78kXJ5zsRMTuWOSp0uqI
# 4         2.325060  ChIJT1aX0LVx5kcRYawv-DeO4qU
# ...            ...                          ...
# 625133 -122.204757                         None
# 625134 -118.412804                         None
# 625135  -73.101901  ChIJY2Ubpu836IkRqyIH_SEtfo4
# 625136  -96.411831                         None
# 625137  121.641299  ChIJnbcpvw8oZjQR7Lax5V6ivvY
#
# [625138 rows x 5 columns]>

# %%
# Load booking.com Data
root_dir = 'C:/Users/lucas/Desktop/VisLab/country/United-States-of-America'
bookingData = load_sharded_dataset(root_dir)
bookingData.info
# Out:
# after making list
# after try
# No files found in directory: C:/Users/lucas/Desktop/VisLab/country/United-States-of-America
# No files found in directory: C:/Users/lucas/Desktop/VisLab/country/United-States-of-America\Alabama
# No files found in directory: C:/Users/lucas/Desktop/VisLab/country/United-States-of-America\Alaska
# No files found in directory: C:/Users/lucas/Desktop/VisLab/country/United-States-of-America\Arizona
# No files found in directory: C:/Users/lucas/Desktop/VisLab/country/United-States-of-America\Arkansas
# No files found in directory: C:/Users/lucas/Desktop/VisLab/country/United-States-of-America\California
# No files found in directory: C:/Users/lucas/Desktop/VisLab/country/United-States-of-America\Colorado
# No files found in directory: C:/Users/lucas/Desktop/VisLab/country/United-States-of-America\Connecticut
# No files found in directory: C:/Users/lucas/Desktop/VisLab/country/United-States-of-America\Delaware
# No files found in directory: C:/Users/lucas/Desktop/VisLab/country/United-States-of-America\Florida
# No files found in directory: C:/Users/lucas/Desktop/VisLab/country/United-States-of-America\Georgia
# No files found in directory: C:/Users/lucas/Desktop/VisLab/country/United-States-of-America\Idaho
# No files found in directory: C:/Users/lucas/Desktop/VisLab/country/United-States-of-America\Illinois
# No files found in directory: C:/Users/lucas/Desktop/VisLab/country/United-States-of-America\Indiana
# No files found in directory: C:/Users/lucas/Desktop/VisLab/country/United-States-of-America\Iowa
# No files found in directory: C:/Users/lucas/Desktop/VisLab/country/United-States-of-America\Kansas
# No files found in directory: C:/Users/lucas/Desktop/VisLab/country/United-States-of-America\Kauai
# No files found in directory: C:/Users/lucas/Desktop/VisLab/country/United-States-of-America\Kentucky
# No files found in directory: C:/Users/lucas/Desktop/VisLab/country/United-States-of-America\Louisiana
# No files found in directory: C:/Users/lucas/Desktop/VisLab/country/United-States-of-America\Maine
# No files found in directory: C:/Users/lucas/Desktop/VisLab/country/United-States-of-America\Martha's-Vineyard
# No files found in directory: C:/Users/lucas/Desktop/VisLab/country/United-States-of-America\Wisconsin
# No files found in directory: C:/Users/lucas/Desktop/VisLab/country/United-States-of-America\Wyoming
# Loaded 5154 files, combined into one DataFrame.
# <bound method DataFrame.info of                                              hotel_name  \
# 0               1001 Atelier Studios (Hotel), Sun Valle
# 1                       1069 Atelier (Hotel), Sun Valle
# 2                             112 Motel (Hotel), Medfor
# 3     1886 Crescent Hotel and Spa (Hotel), Eureka Sp...
# 4         1905 Basin Park Hotel (Hotel), Eureka Springs
# ...                                                 ...
# 4938                           motel6 (Hotel), La Cross
# 4939                        royal inn (Motel), Lovelock
# 4940      stayAPT Suites College Station (Hotel), Bryan
# 4941                  stayAPT Suites Montgomery (Hotel)
# 4942  stayAPT Suites San Antonio Randolph (Live Oak)...
#
#                                                 address     rating  \
# 0                      Sun Valley, 83353, United States        7.8
# 1                      Sun Valley, 83353, United States          9
# 2     2001 Route 112, Medford, NY 11763, United Stat...        8.6
# 3     75 Prospect Avenue, Eureka Springs, AR 72632, ...        8.4
# 4                                     Address not found        8.3
# ...                                                 ...        ...
# 4938  2150 Rose Street, La Crosse, WI 54603, United ...  No Rating
# 4939  1435 CORNELL AVE, Lovelock, NV 89419, United S...        7.6
# 4940                                  Address not found        9.3
# 4941  5000 Woodmere Boulevard, Montgomery, AL 36106,...        8.4
# 4942  7645 North Loop 1604 East, Live Oak, TX 78233,...        8.5
#
#                                                     url  \
# 0     https://www.booking.com/hotel/us/1001-atelier-...
# 1     https://www.booking.com/hotel/us/1069-atelier....
# 2     https://www.booking.com/hotel/us/112-motel.htm...
# 3     https://www.booking.com/hotel/us/eureka-spring...
# 4     https://www.booking.com/hotel/us/eureka-spring...
# ...                                                 ...
# 4938  https://www.booking.com/hotel/us/motel6-la-cro...
# 4939  https://www.booking.com/hotel/us/royal-inn-lov...
# 4940  https://www.booking.com/hotel/us/stayapt-suite...
# 4941  https://www.booking.com/hotel/us/stayapt-suite...
# 4942  https://www.booking.com/hotel/us/stayapt-suite...
#
#                                                  images   latitude   longitude
# 0     [https://cf.bstatic.com/xdata/images/hotel/max...  43.695167 -114.348964
# 1     [https://cf.bstatic.com/xdata/images/hotel/max...  43.695215 -114.347752
# 2     [https://cf.bstatic.com/xdata/images/hotel/max...  40.806998  -73.002407
# 3     [https://cf.bstatic.com/xdata/images/hotel/max...  36.408375  -93.737454
# 4     [https://cf.bstatic.com/xdata/images/hotel/max...  36.402324  -93.737032
# ...                                                 ...        ...         ...
# 4938  [https://cf.bstatic.com/xdata/images/hotel/max...  43.854096  -91.245683
# 4939  [https://cf.bstatic.com/xdata/images/hotel/max...  40.185105 -118.471391
# 4940  [https://cf.bstatic.com/xdata/images/hotel/max...  30.647879  -96.302921
# 4941  [https://cf.bstatic.com/xdata/images/hotel/max...  32.357944  -86.218679
# 4942  [https://cf.bstatic.com/xdata/images/hotel/max...  29.573543  -98.336480
#
# [4943 rows x 7 columns]>

# %%
bookingData.info
# Out:
# <bound method DataFrame.info of                                              hotel_name  \
# 0               1001 Atelier Studios (Hotel), Sun Valle
# 1                       1069 Atelier (Hotel), Sun Valle
# 2                             112 Motel (Hotel), Medfor
# 3     1886 Crescent Hotel and Spa (Hotel), Eureka Sp...
# 4         1905 Basin Park Hotel (Hotel), Eureka Springs
# ...                                                 ...
# 4938                           motel6 (Hotel), La Cross
# 4939                        royal inn (Motel), Lovelock
# 4940      stayAPT Suites College Station (Hotel), Bryan
# 4941                  stayAPT Suites Montgomery (Hotel)
# 4942  stayAPT Suites San Antonio Randolph (Live Oak)...
#
#                                                 address     rating  \
# 0                      Sun Valley, 83353, United States        7.8
# 1                      Sun Valley, 83353, United States          9
# 2     2001 Route 112, Medford, NY 11763, United Stat...        8.6
# 3     75 Prospect Avenue, Eureka Springs, AR 72632, ...        8.4
# 4                                     Address not found        8.3
# ...                                                 ...        ...
# 4938  2150 Rose Street, La Crosse, WI 54603, United ...  No Rating
# 4939  1435 CORNELL AVE, Lovelock, NV 89419, United S...        7.6
# 4940                                  Address not found        9.3
# 4941  5000 Woodmere Boulevard, Montgomery, AL 36106,...        8.4
# 4942  7645 North Loop 1604 East, Live Oak, TX 78233,...        8.5
#
#                                                     url  \
# 0     https://www.booking.com/hotel/us/1001-atelier-...
# 1     https://www.booking.com/hotel/us/1069-atelier....
# 2     https://www.booking.com/hotel/us/112-motel.htm...
# 3     https://www.booking.com/hotel/us/eureka-spring...
# 4     https://www.booking.com/hotel/us/eureka-spring...
# ...                                                 ...
# 4938  https://www.booking.com/hotel/us/motel6-la-cro...
# 4939  https://www.booking.com/hotel/us/royal-inn-lov...
# 4940  https://www.booking.com/hotel/us/stayapt-suite...
# 4941  https://www.booking.com/hotel/us/stayapt-suite...
# 4942  https://www.booking.com/hotel/us/stayapt-suite...
#
#                                                  images   latitude   longitude
# 0     [https://cf.bstatic.com/xdata/images/hotel/max...  43.695167 -114.348964
# 1     [https://cf.bstatic.com/xdata/images/hotel/max...  43.695215 -114.347752
# 2     [https://cf.bstatic.com/xdata/images/hotel/max...  40.806998  -73.002407
# 3     [https://cf.bstatic.com/xdata/images/hotel/max...  36.408375  -93.737454
# 4     [https://cf.bstatic.com/xdata/images/hotel/max...  36.402324  -93.737032
# ...                                                 ...        ...         ...
# 4938  [https://cf.bstatic.com/xdata/images/hotel/max...  43.854096  -91.245683
# 4939  [https://cf.bstatic.com/xdata/images/hotel/max...  40.185105 -118.471391
# 4940  [https://cf.bstatic.com/xdata/images/hotel/max...  30.647879  -96.302921
# 4941  [https://cf.bstatic.com/xdata/images/hotel/max...  32.357944  -86.218679
# 4942  [https://cf.bstatic.com/xdata/images/hotel/max...  29.573543  -98.336480
#
# [4943 rows x 7 columns]>

# %%
cleanBookingData, cleanTrafficData = clean_hotel_names(bookingData, traffickCamData)
# Out:
# <class 'numpy.ndarray'>

# %%
print(cleanBookingData)
# Out:
#       index                    cleanedHotelName   latitude   longitude  \
# 0         0         1001elier studios sun valle  43.695167 -114.348964
# 1         1                 1069elier sun valle  43.695215 -114.347752
# 2         2                         112  medfor  40.806998  -73.002407
# 3         3    1886 crescent spa eureka springs  36.408375  -93.737454
# 4         4     1905 basin park  eureka springs  36.402324  -93.737032
# ...     ...                                 ...        ...         ...
# 4938   4938                          6 la cross  43.854096  -91.245683
# 4939   4939                      royal lovelock  40.185105 -118.471391
# 4940   4940       stayapt college station bryan  30.647879  -96.302921
# 4941   4941                  stayapt montgomery  32.357944  -86.218679
# 4942   4942  stayapt santonio randolph live oak  29.573543  -98.336480
#
#                                                     url  \
# 0     https://www.booking.com/hotel/us/1001-atelier-...
# 1     https://www.booking.com/hotel/us/1069-atelier....
# 2     https://www.booking.com/hotel/us/112-motel.htm...
# 3     https://www.booking.com/hotel/us/eureka-spring...
# 4     https://www.booking.com/hotel/us/eureka-spring...
# ...                                                 ...
# 4938  https://www.booking.com/hotel/us/motel6-la-cro...
# 4939  https://www.booking.com/hotel/us/royal-inn-lov...
# 4940  https://www.booking.com/hotel/us/stayapt-suite...
# 4941  https://www.booking.com/hotel/us/stayapt-suite...
# 4942  https://www.booking.com/hotel/us/stayapt-suite...
#
#                                                  images
# 0     [https://cf.bstatic.com/xdata/images/hotel/max...
# 1     [https://cf.bstatic.com/xdata/images/hotel/max...
# 2     [https://cf.bstatic.com/xdata/images/hotel/max...
# 3     [https://cf.bstatic.com/xdata/images/hotel/max...
# 4     [https://cf.bstatic.com/xdata/images/hotel/max...
# ...                                                 ...
# 4938  [https://cf.bstatic.com/xdata/images/hotel/max...
# 4939  [https://cf.bstatic.com/xdata/images/hotel/max...
# 4940  [https://cf.bstatic.com/xdata/images/hotel/max...
# 4941  [https://cf.bstatic.com/xdata/images/hotel/max...
# 4942  [https://cf.bstatic.com/xdata/images/hotel/max...
#
# [4943 rows x 6 columns]

# %%
cleanTrafficData.head
# Out:
# <bound method NDFrame.head of                                        cleanedHotelName   latitude  \
# 0                                     super 8 frederick  39.402160
# 1       extended stay america fairbanks old airport way  64.835380
# 2                   hilton hangzhou qiandao lake resort  29.608190
# 3                                         taj lands end  19.043910
# 4           helzear montparnasse rive gauche apartments  48.834660
# ...                                                 ...        ...
# 625133      hyatt regency lake washington seattle’sport  47.503043
# 625134                               the beverly hilton  34.066370
# 625135                       homewood hilton ronkonkoma  40.812062
# 625136                                choctaw durant ok  33.958543
# 625137                                                   24.125850
#
#          longitude                    places_id
# 0       -77.408420  ChIJCWJjR0HayYkRAfWSLQl85IQ
# 1      -147.823300  ChIJqbFJVhdbMlERYHgGtF-Gv8w
# 2       119.072900  ChIJDZWWXAOLSTQR4JoKtpTbZEE
# 3        72.818790  ChIJSRH78kXJ5zsRMTuWOSp0uqI
# 4         2.325060  ChIJT1aX0LVx5kcRYawv-DeO4qU
# ...            ...                          ...
# 625133 -122.204757
# 625134 -118.412804
# 625135  -73.101901  ChIJY2Ubpu836IkRqyIH_SEtfo4
# 625136  -96.411831
# 625137  121.641299  ChIJnbcpvw8oZjQR7Lax5V6ivvY
#
# [625138 rows x 4 columns]>

# %%
matches = match_hotels(cleanBookingData, cleanTrafficData)
print(len(matches))
# Out:
# Booking Hotel: 112  medfor
#   Matched Traffic Hotel: 112, Latitude: 40.80717, Longitude: -73.00297, Score: 100.0, Distance: 0.0005886875232237542
# -----
# Booking Hotel: 1886 crescent spa eureka springs
#   Matched Traffic Hotel: 1886 crescent  spa, Latitude: 36.40755, Longitude: -93.73902, Score: 100.0, Distance: 0.0017695296342504104
# -----
# Booking Hotel: 1905 basin park  eureka springs
#   Matched Traffic Hotel: basin park, Latitude: 36.4022, Longitude: -93.73719, Score: 100.0, Distance: 0.0002007286051679119
# -----
# Booking Hotel: 1912  sumter
#   Matched Traffic Hotel: 1912, Latitude: 33.92623, Longitude: -80.3431, Score: 100.0, Distance: 0.0001734156855686754
# -----
# Booking Hotel: 21c museum cincinnati
#   Matched Traffic Hotel: 21c museum cincinnati, Latitude: 39.10313, Longitude: -84.5118, Score: 100.0, Distance: 0.00010397228958961612
# -----
# Booking Hotel: a cape cod ocean manor hyannis
#   Matched Traffic Hotel: cape cod ocean manor, Latitude: 41.63892, Longitude: -70.28002, Score: 100.0, Distance: 0.00023239184603383284
# -----
# Booking Hotel: ac marriott cincinnati banks
#   Matched Traffic Hotel: ac cincinnati banks, Latitude: 39.09694, Longitude: -84.50858, Score: 100.0, Distance: 0.00019524855954058734
# -----
# Booking Hotel: ac marriott san jose downtown
#   Matched Traffic Hotel: ac marriott san jose downtown, Latitude: 37.33342, Longitude: -121.89627, Score: 100.0, Distance: 0.00022601991062264702
# -----
# Booking Hotel: apm  martinsburg
#   Matched Traffic Hotel: apm, Latitude: 39.49139, Longitude: -77.96003, Score: 100.0, Distance: 4.99999999163947e-06
#   Matched Traffic Hotel: apm, Latitude: 39.4916476, Longitude: -77.9598479, Score: 100.0, Distance: 0.0003153638691996681
# -----
# Booking Hotel: abode memphis  downtown madison ave apartment
#   Matched Traffic Hotel: madison, Latitude: 35.14536, Longitude: -90.05324, Score: 100.0, Distance: 0.0007823792239086506
# -----
# Booking Hotel: acadia ocean view  bar harbo
#   Matched Traffic Hotel: acadia ocean view, Latitude: 44.4313472556364, Longitude: -68.26166220015683, Score: 100.0, Distance: 7.29271740787832e-05
# -----
# Booking Hotel: affordable lexington
#   Matched Traffic Hotel: affordable lexington, Latitude: 35.78206, Longitude: -80.31314, Score: 100.0, Distance: 0.000437836849289295
# -----
# Booking Hotel: affordable wilson
#   Matched Traffic Hotel: affordable wilson, Latitude: 35.73193, Longitude: -77.95394, Score: 100.0, Distance: 0.0006648103477643888
# -----
# Booking Hotel: airlie warrenton
#   Matched Traffic Hotel: airlie, Latitude: 38.75683, Longitude: -77.79406, Score: 100.0, Distance: 0.0004119518822611839
# -----
# Booking Hotel: albion  miami beach
#   Matched Traffic Hotel: albion beach, Latitude: 25.79104, Longitude: -80.1307, Score: 100.0, Distance: 0.00018168068085543297
# -----
# Booking Hotel: allure of fort myers
#   Matched Traffic Hotel: allure, Latitude: 26.55668, Longitude: -81.90771, Score: 100.0, Distance: 0.0006720215770356814
# -----
# Booking Hotel: aloft beachwood
#   Matched Traffic Hotel: aloft beachwood, Latitude: 41.45374, Longitude: -81.50132, Score: 100.0, Distance: 0.0025340571245757813
#   Matched Traffic Hotel: aloft, Latitude: 41.4546217, Longitude: -81.4995135, Score: 100.0, Distance: 0.0008046160392395463
# -----
# Booking Hotel: aloft bolingbrook
#   Matched Traffic Hotel: aloft bolingbrook, Latitude: 41.7146, Longitude: -88.03943, Score: 100.0, Distance: 0.0006482329788656605
#   Matched Traffic Hotel: aloft, Latitude: 41.7141266157415, Longitude: -88.0389045238682, Score: 100.0, Distance: 0.00012548746949440098
# -----
# Booking Hotel: aloft dallas euless
#   Matched Traffic Hotel: aloft dallas euless, Latitude: 32.87439, Longitude: -97.10284, Score: 100.0, Distance: 0.0020728658904992864
#   Matched Traffic Hotel: aloft dallas euless, Latitude: 32.8741293816716, Longitude: -97.1030801933664, Score: 100.0, Distance: 0.0023855617622302676
#   Matched Traffic Hotel: aloft dallas euless, Latitude: 32.87445110369035, Longitude: -97.10299192065958, Score: 100.0, Distance: 0.0022026393627304877
# -----
# Booking Hotel: aloft delray beach
#   Matched Traffic Hotel: aloft delray beach, Latitude: 26.45739, Longitude: -80.06824, Score: 100.0, Distance: 0.0003060016339809204
# -----
# Booking Hotel: aloft dulles airport ashburn
#   Matched Traffic Hotel: aloft dulles airport, Latitude: 38.99677, Longitude: -77.48222, Score: 100.0, Distance: 0.00034458054559437316
# -----
# Booking Hotel: aloft jacksonville airport
#   Matched Traffic Hotel: aloft jacksonville airport, Latitude: 30.48102, Longitude: -81.63548, Score: 100.0, Distance: 0.0005568006997995685
# -----
# Booking Hotel: aloft jacksonville tapestry park
#   Matched Traffic Hotel: aloft jacksonville tapestry park, Latitude: 30.25991, Longitude: -81.55439, Score: 100.0, Distance: 0.0004706474264282635
# -----
# Booking Hotel: aloft lexington
#   Matched Traffic Hotel: aloft lexington, Latitude: 42.44473, Longitude: -71.26151, Score: 100.0, Distance: 0.0013272929851745263
# -----
# Booking Hotel: aloft miami doral
#   Matched Traffic Hotel: aloft miami doral, Latitude: 25.80388, Longitude: -80.36925, Score: 100.0, Distance: 0.00031760365237084063
# -----
# Booking Hotel: aloft nashville franklin
#   Matched Traffic Hotel: aloft, Latitude: 35.9516735811087, Longitude: -86.8142420761678, Score: 100.0, Distance: 0.0001843352720047004
# -----
# Booking Hotel: aloft bend
#   Matched Traffic Hotel: aloft bend, Latitude: 41.6767, Longitude: -86.25206, Score: 100.0, Distance: 0.00034910743331969136
# -----
# Booking Hotel: amelia beach fernandina beach
#   Matched Traffic Hotel: amelia beach, Latitude: 30.6388, Longitude: -81.43748, Score: 100.0, Distance: 0.00018122878275716168
# -----
# Booking Hotel: americby wyndham blackduck
#   Matched Traffic Hotel: americby wyndham blackduck, Latitude: 47.73036, Longitude: -94.55419, Score: 100.0, Distance: 0.0005328882683694711
# -----
# Booking Hotel: americby wyndham forest lake
#   Matched Traffic Hotel: americby wyndham forest lake, Latitude: 45.27949, Longitude: -93.0001, Score: 100.0, Distance: 0.0015427851438222957
# -----
# Booking Hotel: americby wyndham jackson
#   Matched Traffic Hotel: amsterdam, Latitude: 41.05459, Longitude: -73.52963, Score: 100.0, Distance: 0.00013695303464968589
# -----
# Booking Hotel: anchorage lakeport inn
#   Matched Traffic Hotel: anchorage, Latitude: 39.04795, Longitude: -122.91508, Score: 100.0, Distance: 9.055385138186931e-05
# -----
# Booking Hotel: andaz napa  a concept hyatt
#   Matched Traffic Hotel: andaz napa a concept hyatt, Latitude: 38.29746, Longitude: -122.28898, Score: 100.0, Distance: 0.0002628439552397114
# -----
# Booking Hotel: appomattox
#   Matched Traffic Hotel: appomattox, Latitude: 37.36749, Longitude: -78.82982, Score: 100.0, Distance: 0.0005846385383224246
# -----
# Booking Hotel: archer boston burlington
#   Matched Traffic Hotel: archer boston/burlington, Latitude: 42.48772, Longitude: -71.2241, Score: 100.0, Distance: 0.00023252225699417264
# -----
# Booking Hotel: archer napa
#   Matched Traffic Hotel: archer napa, Latitude: 38.29819, Longitude: -122.28747, Score: 100.0, Distance: 0.0003013115995137694
# -----
# Booking Hotel: aspen select rochester
#   Matched Traffic Hotel: aspen, Latitude: 44.02164, Longitude: -92.48184, Score: 100.0, Distance: 0.0003083096179122191
#   Matched Traffic Hotel: aspen select, Latitude: 44.02166, Longitude: -92.48215, Score: 100.0, Distance: 7.801807803778616e-05
# -----
# Booking Hotel: aspen  rochester
#   Matched Traffic Hotel: aspen, Latitude: 44.02164, Longitude: -92.48184, Score: 100.0, Distance: 8.910831331034945e-05
# -----
# Booking Hotel: athenaeum  chautauqua
#   Matched Traffic Hotel: athenaeum, Latitude: 42.20838, Longitude: -79.46327, Score: 100.0, Distance: 2.236067978209548e-06
# -----
# Booking Hotel: atlanta marriottgalleria
#   Matched Traffic Hotel: atlanta marriottgalleria, Latitude: 33.89773, Longitude: -84.4672, Score: 100.0, Distance: 7.103663281091871e-05
# -----
# Booking Hotel: atlantic  wall township
#   Matched Traffic Hotel: atlantic, Latitude: 40.15868, Longitude: -74.05297, Score: 100.0, Distance: 0.0012932416371618718
# -----
# Booking Hotel: atria rv mcgregor
#   Matched Traffic Hotel: atria rv mcgregor, Latitude: 31.44259, Longitude: -97.41351, Score: 100.0, Distance: 0.00048259714048001773
# -----
# Booking Hotel: auburn place  cape girardeau
#   Matched Traffic Hotel: auburn place, Latitude: 37.30121, Longitude: -89.57728, Score: 100.0, Distance: 0.0004995087586779058
#   Matched Traffic Hotel: auburn place, Latitude: 37.3011680965105, Longitude: -89.5778924724581, Score: 100.0, Distance: 0.00014758096070567912
# -----
# Booking Hotel: aurora park cottages calistoga
#   Matched Traffic Hotel: aurora park cottages, Latitude: 38.57763, Longitude: -122.58869, Score: 100.0, Distance: 0.0005747068687610009
# -----
# Booking Hotel: autocamp russian river guernevill
#   Matched Traffic Hotel: autocamp russian river, Latitude: 38.49658, Longitude: -123.00896, Score: 100.0, Distance: 0.0007745735999209463
# -----
# Booking Hotel: avon old farms
#   Matched Traffic Hotel: avon old farms, Latitude: 41.80586, Longitude: -72.81727, Score: 100.0, Distance: 0.002389085234479663
# -----
# Booking Hotel: ayres seal beach
#   Matched Traffic Hotel: ayres seal beach, Latitude: 33.77677, Longitude: -118.0729, Score: 100.0, Distance: 0.0011481920571060932
# -----
# Booking Hotel: ayres mission viejo  lake forest
#   Matched Traffic Hotel: ayres mission viejo, Latitude: 33.65381, Longitude: -117.6272, Score: 100.0, Distance: 5.954670436714004e-05
#   Matched Traffic Hotel: ayres, Latitude: 33.6542124906868, Longitude: -117.627714341616, Score: 100.0, Distance: 0.00068805753860745
#   Matched Traffic Hotel: ayres mission viejo, Latitude: 33.6547081126214, Longitude: -117.627663631102, Score: 100.0, Distance: 0.0010219387277179265
# -----
# Booking Hotel: best western plus monica royale  greenvill
#   Matched Traffic Hotel: best western plus monica royale, Latitude: 33.09433, Longitude: -96.11224, Score: 100.0, Distance: 0.0020189976731018484
# -----
# Booking Hotel: barrister's bed breakfast seneca fall
#   Matched Traffic Hotel: barrister's bed breakfast, Latitude: 42.91474, Longitude: -76.79372, Score: 100.0, Distance: 0.00015323083893675505
# -----
# Booking Hotel: baugh surestay collection best western logan
#   Matched Traffic Hotel: best western baugh, Latitude: 41.72829, Longitude: -111.83515, Score: 100.0, Distance: 0.00015997444859079516
# -----
# Booking Hotel: bavarian lodge frankenmut
#   Matched Traffic Hotel: bavarian lodge, Latitude: 43.3263943, Longitude: -83.7372209, Score: 100.0, Distance: 0.0030172233388470757
#   Matched Traffic Hotel: bavarian lodge, Latitude: 43.326646657701, Longitude: -83.7370243483072, Score: 100.0, Distance: 0.0032129307640589118
# -----
# Booking Hotel: baymont  covington
#   Matched Traffic Hotel: baymont  covington, Latitude: 33.6162, Longitude: -83.84408, Score: 100.0, Distance: 0.001321576484361366
# -----
# Booking Hotel: baymont wyndham bryan college station
#   Matched Traffic Hotel: baymont  bryan college station, Latitude: 30.69462, Longitude: -96.35977, Score: 100.0, Distance: 0.00032037009848165734
# -----
# Booking Hotel: baymont wyndham cambridge
#   Matched Traffic Hotel: baymont cambridge, Latitude: 39.99477, Longitude: -81.57597, Score: 100.0, Distance: 0.00039861008517263444
# -----
# Booking Hotel: baymont wyndham columbus rickenbacker
#   Matched Traffic Hotel: baymont columbus / rickenbacker, Latitude: 39.82282, Longitude: -82.93695, Score: 100.0, Distance: 0.0007972450721130387
# -----
# Booking Hotel: baymont wyndham decatur
#   Matched Traffic Hotel: baymont  decatur, Latitude: 33.22831, Longitude: -97.59242, Score: 100.0, Distance: 0.00320754243931597
# -----
# Booking Hotel: baymont wyndham des moines
#   Matched Traffic Hotel: baymont  des moines, Latitude: 41.64566, Longitude: -93.60009, Score: 100.0, Distance: 0.00040670671804246593
# -----
# Booking Hotel: baymont wyndham eden
#   Matched Traffic Hotel: baymont eden, Latitude: 36.48708, Longitude: -79.73749, Score: 100.0, Distance: 0.0017758873952235098
# -----
# Booking Hotel: baymont wyndham fort myers airport
#   Matched Traffic Hotel: baymont fort myers airport, Latitude: 26.54842, Longitude: -81.79921, Score: 100.0, Distance: 0.0002664423577425927
# -----
# Booking Hotel: baymont wyndham grand rapids n walker
#   Matched Traffic Hotel: baymont  grand rapids, Latitude: 43.01881, Longitude: -85.72388, Score: 100.0, Distance: 0.00012201639233168323
# -----
# Booking Hotel: baymont wyndham griffin
#   Matched Traffic Hotel: baymont  griffin, Latitude: 33.28714, Longitude: -84.29196, Score: 100.0, Distance: 0.0003235601860508517
# -----
# Booking Hotel: baymont wyndham harvard
#   Matched Traffic Hotel: baymont  harvard, Latitude: 42.39751, Longitude: -88.61218, Score: 100.0, Distance: 0.0005092426498820575
# -----
# Booking Hotel: baymont wyndham hays
#   Matched Traffic Hotel: baymont hays, Latitude: 38.89592, Longitude: -99.31787, Score: 100.0, Distance: 0.0014528628852764004
# -----
# Booking Hotel: baymont wyndham litchfield
#   Matched Traffic Hotel: baymont litchfield, Latitude: 39.17525, Longitude: -89.67226, Score: 100.0, Distance: 0.000883951305494532
# -----
# Booking Hotel: baymont wyndham marshfield
#   Matched Traffic Hotel: baymont, Latitude: 44.68903, Longitude: -90.15645, Score: 100.0, Distance: 0.0002923439754822491
# -----
# Booking Hotel: baymont wyndham modesto salida
#   Matched Traffic Hotel: baymont  modesto salida, Latitude: 37.69883, Longitude: -121.07424, Score: 100.0, Distance: 0.003989980508082648
# -----
# Booking Hotel: baymont wyndham montgomery al
#   Matched Traffic Hotel: baymont montgomery, Latitude: 32.36543, Longitude: -86.21018, Score: 100.0, Distance: 0.0022741426956067083
# -----
# Booking Hotel: baymont wyndham mount vernon renfro valley
#   Matched Traffic Hotel: baymont  mount vernon renfro valley, Latitude: 37.38218, Longitude: -84.32997, Score: 100.0, Distance: 0.00048764983677215677
# -----
# Booking Hotel: baymont wyndham perryton
#   Matched Traffic Hotel: baymont perryton, Latitude: 36.37446, Longitude: -100.80255, Score: 100.0, Distance: 0.00012218428703746363
# -----
# Booking Hotel: baymont wyndham plainfield indianapolis arpt
#   Matched Traffic Hotel: baymont plainfield/indianapolis arpt, Latitude: 39.67442, Longitude: -86.37274, Score: 100.0, Distance: 0.0008543686924368439
#   Matched Traffic Hotel: baymont wyndham plainfield/ indianapolis arpt, Latitude: 39.6734756, Longitude: -86.3736089, Score: 100.0, Distance: 0.0004299172182968664
# -----
# Booking Hotel: baymont wyndham warrenton
#   Matched Traffic Hotel: baymont  warrenton, Latitude: 38.73129, Longitude: -77.77441, Score: 100.0, Distance: 0.0019657536052331364
# -----
# Booking Hotel: baymont wyndham winchester
#   Matched Traffic Hotel: baymont wyndham winchester, Latitude: 38.0113351, Longitude: -84.1717847, Score: 100.0, Distance: 0.00028489734992973676
# -----
# Booking Hotel: bayside resort  yarmout
#   Matched Traffic Hotel: bayside resort, Latitude: 41.65544, Longitude: -70.25618, Score: 100.0, Distance: 0.0003457040822663917
# -----
# Booking Hotel: beacher's lodge crescent beach
#   Matched Traffic Hotel: beacher's lodge, Latitude: 29.7672, Longitude: -81.25281, Score: 100.0, Distance: 0.0006988756148252097
# -----
# Booking Hotel: bear country cabin upper canyon vacation home ruidoso
#   Matched Traffic Hotel: bear country cabin, Latitude: 33.33294, Longitude: -105.68969, Score: 100.0, Distance: 0.000164757397406031
# -----
# Booking Hotel: bedford
#   Matched Traffic Hotel: bedford, Latitude: 42.49489, Longitude: -71.28547, Score: 100.0, Distance: 0.0005681363228094723
# -----
# Booking Hotel: bel abri napa valley inn
#   Matched Traffic Hotel: bel abri napa valley inn, Latitude: 38.29676, Longitude: -122.30033, Score: 100.0, Distance: 0.00027402552435769925
#   Matched Traffic Hotel: bel abri napa valley inn, Latitude: 38.2971223, Longitude: -122.3006956, Score: 100.0, Distance: 0.00037441615616179777
# -----
# Booking Hotel: belfast harbor
#   Matched Traffic Hotel: belfast harbor inn, Latitude: 44.43146, Longitude: -68.9901, Score: 100.0, Distance: 0.0004719957934137632
# -----
# Booking Hotel: bella vista lake geneva
#   Matched Traffic Hotel: bella vista, Latitude: 42.58866, Longitude: -88.43321, Score: 100.0, Distance: 0.0007452430231788637
# -----
# Booking Hotel: best western apache junction
#   Matched Traffic Hotel: best western apache junction inn, Latitude: 33.41506, Longitude: -111.55799, Score: 100.0, Distance: 0.000396295344407535
# -----
# Booking Hotel: best western bastrop pines
#   Matched Traffic Hotel: best western bastrop pines inn, Latitude: 30.1094, Longitude: -97.35646, Score: 100.0, Distance: 0.0007378685519809576
# -----
# Booking Hotel: best western brady
#   Matched Traffic Hotel: best western brady inn, Latitude: 31.11114, Longitude: -99.33458, Score: 100.0, Distance: 0.0001307194266274347
# -----
# Booking Hotel: best western butner creedmoor
#   Matched Traffic Hotel: best western butner creedmoor inn, Latitude: 36.15093, Longitude: -78.7258, Score: 100.0, Distance: 0.0013017774311202925
# -----
# 2241

# %%
print(matches["candlewood alabaster"])
# Out:
# [{'index': 554, 'traffic_hotel_name': 'candlewood alabaster', 'url': 'https://www.booking.com/hotel/us/candlewood-suites-alabaster.html?aid=304142&label=gen173nr-1FCAMo7AFCCWFsYWJhc3RlckgzWARonQKIAQGYATG4AQfIAQ_YAQHoAQH4AQKIAgGoAgO4AqOtsrYGwAIB0gIkMjdmOGMwMjMtNzk1Zi00MmRlLTgwYzgtYWE5ZWI1MThiNjE42AIF4AIB&sid=4f648819a52e44b88635f568c13b1d71&dest_id=20000038&dest_type=city&dist=0&group_adults=2&group_children=0&hapos=2&hpos=2&no_rooms=1&req_adults=2&req_children=0&room1=A%2CA&sb_price_type=total&sr_order=popularity&srepoch=1724684074&srpvid=7a6268cf5f820527&type=total&ucfs=1&activeTab=photosGallery#close-lightbox', 'latitude': 33.2329, 'longitude': -86.80002, 'similarity_score': 100.0, 'distance': 0.0007507592756763593, 'images': ['https://cf.bstatic.com/xdata/images/hotel/max1024x768/234835142.jpg?k=57aebee39c82bc465ca7168c7ff403518ce7bd05bbda5801f38a3d3dc9d026d8&o=&hp=1', 'https://cf.bstatic.com/xdata/images/hotel/max1024x768/325325025.jpg?k=622ea9ff3c20e73d073f4c8e41122898c8b8c09c91ace304a5732c1e40fb0f69&o=&hp=1', 'https://cf.bstatic.com/xdata/images/hotel/max1024x768/325325012.jpg?k=def599cd977e09d1b75606d17eb94a82775befc480b88a9d9ff56bd9bb0819e6&o=&hp=1', 'https://cf.bstatic.com
data/images/hotel/max1024x768/234833953.jpg?k=c8eef4823173b929afdfa39a9e3bfcb7514a33879a59bdbd544483bfb9191997&o=&hp=1', 'https://cf.bstatic.com/xdata/images/hotel/max1024x768/325576449.jpg?k=99f9a75e33381769d6e78f54babf20b3dbb1f2855bfd39e2d6883ce3fe614dc7&o=&hp=1', 'https://cf.bstatic.com/xdata/images/hotel/max102 ...

# %%
# Testing to see that the hashing works
hash_value = hashlib.md5("https://www.booking.com/hotel/us/candlewood-suites-alabaster.html?aid=304142&label=gen173nr-1FCAMo7AFCCWFsYWJhc3RlckgzWARonQKIAQGYATG4AQfIAQ_YAQHoAQH4AQKIAgGoAgO4AqOtsrYGwAIB0gIkMjdmOGMwMjMtNzk1Zi00MmRlLTgwYzgtYWE5ZWI1MThiNjE42AIF4AIB&sid=4f648819a52e44b88635f568c13b1d71&dest_id=20000038&dest_type=city&dist=0&group_adults=2&group_children=0&hapos=2&hpos=2&no_rooms=1&req_adults=2&req_children=0&room1=A%2CA&sb_price_type=total&sr_order=popularity&srepoch=1724684074&srpvid=7a6268cf5f820527&type=total&ucfs=1&activeTab=photosGallery#close-lightbox".encode('utf-8')).hexdigest()

print(hash_value)

hash_check_bool = predownload_check(hash_value)
# Out:
# b2ee652b30766d8a59c7f62d8c0e14c5
# False

# %%
root_directory = "C:/Users/lucas/Desktop/VisLab/booking_images"

download_all_images(matches, root_directory)
# Out:
# True
# True
# False
# Downloaded: https://cf.bstatic.com/xdata/images/hotel/max1024x768/470429656.jpg?k=c3a12d9b20ae9be4fed717b2b25f584c2a2463ca76ee28f53afeda5822687626&o= -> C:/Users/lucas/Desktop/VisLab/booking_images\00\00\04\434412_f92398fd44987d294a222f15bca78fc6\470429656.jpg
# Downloaded: https://cf.bstatic.com/xdata/images/hotel/max1024x768/470429656.jpg?k=c3a12d9b20ae9be4fed717b2b25f584c2a2463ca76ee28f53afeda5822687626&o=&hp=1 -> C:/Users/lucas/Desktop/VisLab/booking_images\00\00\04\434412_f92398fd44987d294a222f15bca78fc6\470429656.jpg
# Downloaded: https://cf.bstatic.com/xdata/images/hotel/max1024x768/470430284.jpg?k=d74f20619a675f596079d0896cf4f5425ad4b28c84e7d15e9e0dbac4699feefc&o=&hp=1 -> C:/Users/lucas/Desktop/VisLab/booking_images\00\00\04\434412_f92398fd44987d294a222f15bca78fc6\470430284.jpg
# Downloaded: https://cf.bstatic.com/xdata/images/hotel/max1024x768/470434044.jpg?k=17ddbad3df261b19492db967756d114daafc5ca51f3950432eb66d903242839b&o=&hp=1 -> C:/Users/lucas/Desktop/VisLab/booking_images\00\00\04\434412_f92398fd44987d294a222f15bca78fc6\470434044.jpg
# Downloaded: https://cf.bstatic.com/xdata/images/hotel/max1024x768/470433507.jpg?k=eb552ab97ed5bbb52b0e6f742abf6840fe475cc7c3451827c5b2295c74961be8&o=&hp=1 -> C:/Users/lucas/Desktop/VisLab/booking_images\00\00\04\434412_f92398fd44987d294a222f15bca78fc6\470433507.jpg
# Downloaded: https://cf.bstatic.com/xdata/images/hotel/max1024x768/251048547.jpg?k=6113dbe75a460f88a260e6a6fc1a8ca92569b7c849a09980f40731ca44c6a873&o=&hp=1 -> C:/Users/lucas/Desktop/VisLab/booking_images\00\00\04\434412_f92398fd44987d294a222f15bca78fc6\251048547.jpg
# Downloaded: https://cf.bstatic.com/xdata/images/hotel/max1024x768/470429656.jpg?k=c3a12d9b20ae9be4fed717b2b25f584c2a2463ca76ee28f53afeda5822687626&o=&hp=1 -> C:/Users/lucas/Desktop/VisLab/booking_images\00\00\04\434412_f92398fd44987d294a222f15bca78fc6\470429656.jpg
# Finished downloading images for hotel: 1905 basin park  eureka springs
# False
# Downloaded: https://cf.bstatic.com/xdata/images/hotel/max1024x768/232626312.jpg?k=a02a864adbd2a965eb620a52b7e1d2ca30092b7798952a908bef84893fc32da6&o=&hp=1 -> C:/Users/lucas/Desktop/VisLab/booking_images\00\00\05\684999_c02fd16b1f8c360f5ae3008d6752f42e\232626312.jpg
# Downloaded: https://cf.bstatic.com/xdata/images/hotel/max1024x768/532113233.jpg?k=22e1d21520c39caf93862fdd460d122836031d77c1320e5df7cc99189391a32d&o=&hp=1 -> C:/Users/lucas/Desktop/VisLab/booking_images\00\00\05\684999_c02fd16b1f8c360f5ae3008d6752f42e\532113233.jpg
# Downloaded: https://cf.bstatic.com/xdata/images/hotel/max1024x768/150461644.jpg?k=d018f12c45cb5fb8f42882918c4dea69528e0142634fada8404766e8cb026184&o=&hp=1 -> C:/Users/lucas/Desktop/VisLab/booking_images\00\00\05\684999_c02fd16b1f8c360f5ae3008d6752f42e\150461644.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[89], line 3
#       1 root_directory = "C:/Users/lucas/Desktop/VisLab/booking_images"
# ----> 3 download_all_images(matches, root_directory)
#
# Cell In[87], line 24, in download_all_images(matches_dict, root_directory, log_file)
#      22 if predownload_check(hashed_url) == False:
#      23     for image_url in image_urls:
# ---> 24         download_single_image(image_url, save_directory)
#      26     print(f"Finished downloading images for hotel: {hotel_name}")
#      28 else:
#
# Cell In[83], line 17, in download_single_image(url, save_directory)
#      15 # Save the image
#      16 with open(save_path, 'wb') as image_file:
# ---> 17     for chunk in response.iter_content(1024):
#      18         image_file.write(chunk)
#      19 print(f"Downloaded: {url} -> {save_path}")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\requests\models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\urllib3\response.py:1040, in HTTPResponse.stream(self, amt, decode_content)
#    1024 """
#    1025 A generator wrapper for the read() method. A call will block until
#    1026 ``amt`` bytes have been read from the connection or until the
#    (...)
#    1037     'content-encoding' header.
#    1038 """
#    1039 if self.chunked and self.supports_chunked_reads():
# -> 1040     yield from self.read_chunked(amt, decode_content=decode_content)
#    1041 else:
#    1042     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\urllib3\response.py:1184, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1181     return None
#    1183 while True:
# -> 1184     self._update_chunk_length()
#    1185     if self.chunk_left == 0:
#    1186         break
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\urllib3\response.py:1108, in HTTPResponse._update_chunk_length(self)
#    1106 if self.chunk_left is not None:
#    1107     return None
# -> 1108 line = self._fp.fp.readline()  # type: ignore[union-attr]
#    1109 line = line.split(b";", 1)[0]
#    1110 try:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\ssl.py:1314, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1310     if flags != 0:
#    1311         raise ValueError(
#    1312           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1313           self.__class__)
# -> 1314     return self.read(nbytes, buffer)
#    1315 else:
#    1316     return super().recv_into(buffer, nbytes, flags)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\ssl.py:1166, in SSLSocket.read(self, len, buffer)
#    1164 try:
#    1165     if buffer is not None:
# -> 1166         return self._sslobj.read(len, buffer)
#    1167     else:
#    1168         return self._sslobj.read(len)
#
# KeyboardInterrupt:
